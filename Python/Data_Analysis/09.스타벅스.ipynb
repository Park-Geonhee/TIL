# %% [markdown]
# ### 인스타그램 복습

# %%
import pandas as pd
import numpy as np

# %%
location_counts = pd.read_excel('../5_Jeju_Hotplace/files/3_location_counts.xlsx')
location_counts.head()
# Out:
#              Unnamed: 0  place
# 0                  Jeju    271
# 1               Jeju-do    179
# 2  Jungle Book by Alice    108
# 3              Seogwipo     66
# 4         제주도 크리스마스 박물관     59

# %%
location_counts.columns
# Out:
# Index(['Unnamed: 0', 'place'], dtype='object')

# %%
locations = list(location_counts.loc[:,'Unnamed: 0'])
locations[:5]
# list로 묶어주지 않으면 Series 타입으로 저장됨
# 추후 다른 함수 적용할 때 원활하지 않음
# Out:
# ['Jeju', 'Jeju-do', 'Jungle Book by Alice', 'Seogwipo', '제주도 크리스마스 박물관']

# %%
search = '합정 스타벅스'
url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(search)
url
# Out:
# 'https://dapi.kakao.com/v2/local/search/keyword.json?query=합정 스타벅스'

# %%
headers = {
    "Authorization" : "KakaoAK ***"
}

# %%
import requests

# %%
places = requests.get(url, headers = headers).json()['documents']
places
# Out:
# [{'address_name': '서울 마포구 서교동 395-166',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '26572121',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 서교점',
#   'place_url': 'http://place.map.kakao.com/26572121',
#   'road_address_name': '서울 마포구 양화로 78',
#   'x': '126.916980454434',
#   'y': '37.5514601750423'},
#  {'address_name': '서울 마포구 합정동 472',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
#   'distance': '',
#   'id': '2057327896',
#   'phone': '1522-3232',
#   'place_name': '스타벅스 합정점',
#   'place_url': 'http://place.map.kakao.com/2057327896',
#   'road_address_name': '서울 마포구 월드컵로1길 14',
#   'x': '126.91253700818196',
#   'y': '37.54994959743763'},
#  {'address_name': '서울 마포구 서교동 490',
#   'category_group_code': 'CE7',
#   'category_group_name': '카페',
#   'category_name': '음식점 > 카페 > 커피전문점 > 스타벅스',
# ...

# %%
def find_places(searching):
    url = 'http://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
    headers = {
    "Authorization": "KakaoAK ***"
    }
    places = requests.get(url, headers = headers).json()['documents']
    
    place = places[0]
    
    name = place['place_name']
    
    x = place['x']
    y = place['y']
    
    data = [name, x, y, searching]
    
    return data

# %%
find_places('제주공항')
# Out:
# ['제주국제공항', '126.492769004244', '33.5070789578184', '제주공항']

# %%
from tqdm.notebook import tqdm

# %%
locations_inform = []

for location in tqdm(locations[:20]):
    try:
        data = find_places(location)
        locations_inform.append(data)
        time.sleep(1)
    except:
        pass
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
locations_inform
# Out:
# [['Jeju in aA', '126.83650369902168', '33.53833652360498', 'Jeju'],
#  ['서귀포잠수함', '126.558616052674', '33.2393033784206', 'Seogwipo'],
#  ['바이나흐튼 크리스마스박물관', '126.32785786016811', '33.2915720831759', '제주도 크리스마스 박물관'],
#  ['할로비치 본점', '126.2815248933638', '33.30832616522123', '할로비치'],
#  ['제주에인감귤밭', '126.5390139270361', '33.25656069063887', '제주에인감귤밭'],
#  ['제주도', '126.54587355630036', '33.379777816446165', 'Jeju Island'],
#  ['한라산1100고지', '126.462219691112', '33.3580781709788', '1100고지'],
#  ['월정리해수욕장', '126.795805057888', '33.556469394054', '월정리해변'],
#  ['고집돌우럭 중문점', '126.416704762779', '33.2579811121134', '고집돌우럭중문점'],
#  ['석부작박물관', '126.536501983154', '33.2504031491774', '석부작박물관'],
#  ['올레길 16코스(고내-광령 올레)', '126.38979561557086', '33.46649759191228', '제주도 애월읍'],
#  ['알뜨르비행장', '126.271527320164', '33.2047161778831', '알뜨르 비행장'],
#  ['카멜리아힐', '126.370009467525', '33.2896344311608', '카멜리아 힐'],
#  ['제주레포츠랜드', '126.6387551242765', '33.48206819907232', '제주레포츠랜드'],
# ...

# %%
location_inform_df = pd.read_excel('../5_Jeju_Hotplace/files/3_locations.xlsx')
location_counts_df = pd.read_excel('../5_Jeju_Hotplace/files/3_location_counts.xlsx',
                                  index_col = 0)

# %%
location_counts_df.head()
# Out:
#                       place
# Jeju                    271
# Jeju-do                 179
# Jungle Book by Alice    108
# Seogwipo                 66
# 제주도 크리스마스 박물관            59

# %%
location_data = pd.merge(location_inform_df,
                        location_counts_df, how = 'inner',
                        left_on = 'name_official',
                         right_index = True)
location_data
# Out:
#     name_official          경도         위도       인스타위치명  place
# 1          서귀포잠수함  126.558616  33.239303     Seogwipo      1
# 308        서귀포잠수함  126.558616  33.239303       서귀포잠수함      1
# 3            할로비치  127.020826  37.518211         할로비치     51
# 4         제주에인감귤밭  126.539410  33.256610      제주에인감귤밭     48
# 5             제주도  126.545876  33.379777  Jeju Island      4
# ..            ...         ...        ...          ...    ...
# 829      리치망고 협재점  126.251784  33.402414     리치망고 협재점      1
# 831          독개물항  126.251613  33.401890         독개물항      1
# 833         카페오드리  126.297366  33.356905        카페오드리      1
# 837       배블리컨테이너  126.793483  33.556761      배블리컨테이너      1
# 840          신풍목장  126.863724  33.356009         신풍목장      1
#
# [444 rows x 5 columns]

# %%
location_data['name_official'].value_counts()
# Out:
# 오설록티뮤지엄           3
# 서귀포잠수함            2
# 천지연폭포             2
# 빌라드아토             2
# 비자림               2
#                  ..
# 투썸플레이스 제주애월한담점    1
# 하늘고래              1
# 문쏘                1
# 성산일출봉             1
# 신풍목장              1
# Name: name_official, Length: 416, dtype: int64

# %%
location_data = location_data.pivot_table(values = 'place',
                         index = ['name_official','경도','위도'],
                         aggfunc = 'sum')
location_data = location_data.sort_values(by = 'place', ascending = False)
location_data
# Out:
#                                     place
# name_official 경도         위도
# 할로비치          127.020826 37.518211     51
# 제주에인감귤밭       126.539410 33.256610     48
# 석부작박물관        126.536502 33.250403     36
# 위미동백나무군락      126.674731 33.272939     18
# 밥깡패           126.263436 33.410093     16
# ...                                   ...
# 산방산           126.313425 33.241304      1
# 사이카레          126.381107 33.484245      1
# 사락            126.307741 33.228771      1
# 뽕끄랑           126.555112 33.243034      1
# 흑송            129.196513 35.175011      1
#
# [417 rows x 1 columns]

# %%
import folium

# %%
location_data = pd.read_excel('../5_Jeju_Hotplace//files/3_location_inform.xlsx')
location_data
# Out:
#     name_official          경도         위도  place
# 0            73st  126.455109  33.456989      1
# 1            가드망제  126.532954  33.500991      1
# 2              가배  126.505570  33.231541      1
# 3            가시식당  126.771438  33.353060      2
# 4          가시아방국수  126.918072  33.438605      2
# ..            ...         ...        ...    ...
# 412        황궁쟁반짜장  129.110405  35.197355      1
# 413         황우지해안  126.550528  33.241467      2
# 414          훈남횟집  126.667858  33.542086      1
# 415     훈이네고사리육개장  126.533934  33.487956      2
# 416            흑송  129.196513  35.175011      1
#
# [417 rows x 4 columns]

# %%
Mt_Hanla = [33.362500, 126.533694]
map_jeju = folium.Map(location = Mt_Hanla,
                     zoom_start = 10)

#https://deparkes.co.uk/2016/06/10/folium-map-tiles/
#folium.TileLayer('stamenwatercolor').add_to(map_jeju)

for i in range(len(location_data)): # 417
    name = location_data['name_official'][i]
    count = location_data['place'][i]
    size = int(count*2)
    lng = location_data['경도'][i]
    lat = location_data['위도'][i]
    folium.CircleMarker(location = [lat,lng],
                       radius = size,
                       color = 'red',
                       popup = name).add_to(map_jeju)

    
map_jeju
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
from folium.plugins import MarkerCluster

locations = []
names = []

for i in range(len(location_data)):
    data =location_data.iloc[i]
    locations.append([data['위도'], data['경도']])
    names.append(data['name_official'])
    
#print(names)

Mt_Hanla = [33.362500, 126.533694]
map_jeju2 = folium.Map(location = Mt_Hanla, zoom_start = 11)

tiles = ['stamenwatercolor','cartodbpositron',
         'openstreetmap','stamenterrain']

for tile in tiles:
    folium.TileLayer(tile).add_to(map_jeju2)

    
marker_cluster = MarkerCluster(locations = locations,
                              popups = names,
                              name = 'Jeju',
                              overlay = True,
                              control = True
                              )

marker_cluster.add_to(map_jeju2)

folium.LayerControl().add_to(map_jeju2)

map_jeju2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
import wordcloud

# %%
raw_total = pd.read_excel('../5_Jeju_Hotplace/files/1_crawling_raw.xlsx')
raw_total.head()
# Out:
#                                              content        date   like  \
# 0  더 늦기전에 제주도로 떠나쟈😍.#제주핫플레이스 간단히 1탄 모아봄!#제주여행 요 필...  2018-12-07  1,402
# 1  12월에 제주도를 가야하는이유🍊.#제주핫플 모음 끝판왕😍이거 하나면 겨울 #제주여행...  2018-12-03    368
# 2  11월 놓치지 말아야 할 제주 관광.가을바람이 최고조에 이르는 11월추운 겨울을 앞...  2018-11-02    166
# 3  국민학교세대#제주관광#제주살이#제주이주민#아라동주민#삼남매집 #새해첫날#드라이브#명...  2019-01-01     28
# 4  #제주관광 #제주 #돔나이트 #스트레스 #풀자 #춤추며 #땀날려 #가끔은괜찮아 #인...  2019-01-01     12
#
#     place                                               tags
# 0     NaN  ['#제주핫플레이스', '#제주여행', '#제주여행', '#제주도여행', '#제주가...
# 1     NaN  ['#제주핫플', '#제주여행', '#제주', '#제주도', '#제주도맛집', '#...
# 2     NaN  ['#honestin', '#어니스틴', '#제주여행', '#제주', '#제주도',...
# 3  명월국민학교  ['#제주관광', '#제주살이', '#제주이주민', '#아라동주민', '#삼남매집'...
# 4     NaN  ['#제주관광', '#제주', '#돔나이트', '#스트레스', '#풀자', '#춤추...

# %%
raw_total['tags'][0]
# Out:
# "['#제주핫플레이스', '#제주여행', '#제주여행', '#제주도여행', '#제주가볼만한곳', '#제주도핫플', '#제주여행코스', '#제주공항', '#제주도맛집', '#제주맛집', '#제주스냅', '#제주풍경', '#제주사진', '#제주카페', '#제주도카페', '#산굼부리', '#제주도바다', '#귤체험', '#우도', '#제주관광', '#제주도여향지', '#제주여행중', '#삼육오빠', '#제주앓이']"

# %%
tags_total = []

for tags in raw_total['tags']:
    tags_list = tags[2:-2].split("', '")
    for tags in tags_list:
        tags_total.append(tags)
        
tags_total[:10]
# Out:
# ['#제주핫플레이스',
#  '#제주여행',
#  '#제주여행',
#  '#제주도여행',
#  '#제주가볼만한곳',
#  '#제주도핫플',
#  '#제주여행코스',
#  '#제주공항',
#  '#제주도맛집',
#  '#제주맛집']

# %% [markdown]
# ---

# %% [markdown]
# ### 스타벅스

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By

import pandas as pd
import numpy as np

# %%
ser = Service('../chrome_dirver/chromedriver.exe')
driver = webdriver.Chrome(service = ser)

# %%
# url = 'https://www.starbucks.co.kr/store/store_map.do?disp=locale'
# driver.get(url)

# %%
url = 'https://www.starbucks.co.kr/index.do'
driver.get(url)

# %%
seoul_btn = '#container > div > form > fieldset > div \
    > section > article.find_store_cont > article \
    > article:nth-child(4) > div.loca_step1 > div.loca_step1_cont \
    > ul > li:nth-child(1) > a'
driver.find_element(By.CSS_SELECTOR, seoul_btn).click()
# find_elements 아님(s안들어감)

# %%
seoul_all_btn = '#mCSB_2_container > ul > li:nth-child(1) > a'
driver.find_element(By.CSS_SELECTOR, seoul_all_btn).click()

# %% [markdown]
# ---
# 혼자서 크롤링 해보기

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
seoulList = soup.select('li.quickResultLstCon')
len(seoulList)
# Out:
# 568

# %%
seoulList[0]
# Out:
# <li class="quickResultLstCon" data-code="3762" data-hlytag="null" data-index="0" data-lat="37.501087" data-long="127.043069" data-name="역삼아레나빌딩" data-storecd="1509" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="역삼아레나빌딩" data-store="1509" data-yn="N">역삼아레나빌딩  </strong> <p class="result_details">서울특별시 강남구 언주로 425 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>

# %%
seoulList[0].select('strong')[0].text.strip(' ')
# Out:
# '역삼아레나빌딩'

# %%
seoulList[1].select('p')
# Out:
# [<p class="result_details">서울특별시 강남구 강남대로 538 (논현동)<br/>1522-3232</p>]

# %%
adr_num = seoulList[0].select('p')[0].text.strip(' ')
adr_num
# Out:
# '서울특별시 강남구 언주로 425 (역삼동)1522-3232'

# %%
adr_num[:-9]
# Out:
# '서울특별시 강남구 언주로 425 (역삼동)'

# %%
adr_num[-9:]
# Out:
# '1522-3232'

# %%
seoulSB = []
for seoul in seoulList:
    name = seoul.select('strong')[0].text.strip(' ')
    AdrNum = seoul.select('p')[0].text.strip(' ')
    adr = AdrNum[:-9]
    num = AdrNum[-9:]
    seoulSB.append([name, adr, num])
    
seoulSB[:10]
# Out:
# [['역삼아레나빌딩', '서울특별시 강남구 언주로 425 (역삼동)', '1522-3232'],
#  ['논현역사거리', '서울특별시 강남구 강남대로 538 (논현동)', '1522-3232'],
#  ['신사역성일빌딩', '서울특별시 강남구 강남대로 584 (논현동)', '1522-3232'],
#  ['국기원사거리', '서울특별시 강남구 테헤란로 125 (역삼동)', '1522-3232'],
#  ['대치재경빌딩R', '서울특별시 강남구 남부순환로 2947 (대치동)', '1522-3232'],
#  ['봉은사역', '서울특별시 강남구 봉은사로 619 (삼성동)', '1522-3232'],
#  ['압구정윤성빌딩', '서울특별시 강남구 논현로 834 (신사동)', '1522-3232'],
#  ['코엑스별마당', '서울특별시 강남구 영동대로 513 (삼성동)', '1522-3232'],
#  ['삼성역섬유센터R', '서울특별시 강남구 테헤란로 518 (대치동)', '1522-3232'],
#  ['압구정R', '서울특별시 강남구 언주로 861 (신사동)', '1522-3232']]

# %%
seoulSB_df = pd.DataFrame(seoulSB, columns = ['지점명','주소','전화번호'])
seoulSB_df
# Out:
#          지점명                                           주소       전화번호
# 0    역삼아레나빌딩                      서울특별시 강남구 언주로 425 (역삼동)  1522-3232
# 1     논현역사거리                     서울특별시 강남구 강남대로 538 (논현동)  1522-3232
# 2    신사역성일빌딩                     서울특별시 강남구 강남대로 584 (논현동)  1522-3232
# 3     국기원사거리                     서울특별시 강남구 테헤란로 125 (역삼동)  1522-3232
# 4    대치재경빌딩R                   서울특별시 강남구 남부순환로 2947 (대치동)  1522-3232
# ..       ...                                          ...        ...
# 563     사가정역                            서울특별시 중랑구 면목로 310  1522-3232
# 564      상봉역                      서울특별시 중랑구 망우로 307 (상봉동)  1522-3232
# 565    묵동이마트  서울특별시 중랑구 동일로 932 (묵동, 묵동자이아파트) (묵동이마트 B1층)  1522-3232
# 566       묵동        서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  1522-3232
# 567      중화역                       서울특별시 중랑구 봉화산로 35 1,2층  1522-3232
#
# [568 rows x 3 columns]

# %% [markdown]
# ---

# %%
starbucks_soup_list = soup.select('li.quickResultLstCon')
len(soup.select('li.quickResultLstCon'))
# Out:
# 568

# %%
starbucks_store = starbucks_soup_list[0]
starbucks_store
# Out:
# <li class="quickResultLstCon" data-code="3762" data-hlytag="null" data-index="0" data-lat="37.501087" data-long="127.043069" data-name="역삼아레나빌딩" data-storecd="1509" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="역삼아레나빌딩" data-store="1509" data-yn="N">역삼아레나빌딩  </strong> <p class="result_details">서울특별시 강남구 언주로 425 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>

# %%
name = starbucks_store.select('strong')[0].text.strip()

# attribute 에 접근할 때 대괄호 사용
lat = starbucks_store['data-lat'].strip()
long = starbucks_store['data-long'].strip()

# store_type = 'general' or 'reserve'
store_type = starbucks_store.select('i')[0]['class'][0][4:]

# 전화번호의 길이가 다를수 있기에 해당 전처리 방법이 더 적합함.
address = str(starbucks_store.select('p')[0]).split('<br/>')[0].split('>')[1]
tel = str(starbucks_store.select('p')[0]).split('<br/>')[1].split('<')[0]

zeroList = [name,lat,long, store_type, address, tel]
zeroList
# Out:
# ['역삼아레나빌딩',
#  '37.501087',
#  '127.043069',
#  'general',
#  '서울특별시 강남구 언주로 425 (역삼동)',
#  '1522-3232']

# %%
# DataFrame 으로 저장하기
columns = ['매장명','위도','경도','매장타입','주소','전화번호']
seoul_starbucks = []

for starbucks_store in starbucks_soup_list:
    name = starbucks_store.select('strong')[0].text.strip()
    lat = starbucks_store['data-lat'].strip()
    long = starbucks_store['data-long'].strip()
    store_type = starbucks_store.select('i')[0]['class'][0][4:]
    address = str(starbucks_store.select('p')[0]).split('<br/>')[0].split('>')[1]
    tel = str(starbucks_store.select('p')[0]).split('<br/>')[1].split('<')[0]

    lists = [name,lat,long, store_type, address, tel]
    seoul_starbucks.append(lists)
    
seoul_starbucks_df = pd.DataFrame(seoul_starbucks,
                  columns = ['매장명','위도','경도','매장타입','주소','전화번호'])

seoul_starbucks_df.head()
# Out:
#        매장명         위도          경도     매장타입                          주소  \
# 0  역삼아레나빌딩  37.501087  127.043069  general     서울특별시 강남구 언주로 425 (역삼동)
# 1   논현역사거리  37.510178  127.022223  general    서울특별시 강남구 강남대로 538 (논현동)
# 2  신사역성일빌딩  37.514132  127.020563  general    서울특별시 강남구 강남대로 584 (논현동)
# 3   국기원사거리  37.499517  127.031495  general    서울특별시 강남구 테헤란로 125 (역삼동)
# 4  대치재경빌딩R  37.494668  127.062583  reserve  서울특별시 강남구 남부순환로 2947 (대치동)
#
#         전화번호
# 0  1522-3232
# 1  1522-3232
# 2  1522-3232
# 3  1522-3232
# 4  1522-3232

# %%
seoul_starbucks_df.to_excel('./files/seoul_starbucks_list_class.xlsx', index = False)

# %%
import requests

# %%
SEOUL_API_AUTH_KEY = '***'
Open_API = 'GangseoListLoanCompany'

# %%
url = 'http://openAPI.seoul.go.kr:8088/{}/json/{}/1/5/'.format(SEOUL_API_AUTH_KEY, Open_API)

url
# Out:
# 'http://openAPI.seoul.go.kr:8088/6b594d554267656f35355a5a4f7178/json/GangseoListLoanCompany/1/5/'

# %%
result_dict = requests.get(url).json()
result_dict
# Out:
# {'GangseoListLoanCompany': {'list_total_count': 1104,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'BSNS_SE': '대부중개업',
#     'MNG_STATE_CODE': '폐업',
#     'OLD_APV_NO': '2015-서울강서-00033(대부중개업)',
#     'BUP_NM': '주식회사 론마음파트너스대부중개',
#     'REP_NM': '김진영',
#     'UPCHE_GBN': '법인',
#     'WRKR_BUP_TELNO': '02-521-1012',
#     'WRKR_BUP_ADDR': '서울특별시 강서구 등촌동  696번지  세신그린코아빌딩',
#     'WRKR_RD_FULL_ADDR': '서울특별시 강서구 공항대로41길 51, 세신그린코아빌딩 9층 905호 (등촌동)',
#     'WRKR_BUP_POST_NO': '',
#     'APV_YMD': '20210712',
#     'END_APV_YMD': '20240712',
#     'LAST_CLS_YMD': '20220117',
#     'WRKR_ESBMNT_YMD': '20150924',
#     'HOFF_YN': '본점',
#     'LAST_MOD_YMD': '20220118'},
#    {'BSNS_SE': '대부업',
#     'MNG_STATE_CODE': '폐업',
#     'OLD_APV_NO': '2020-서울강서-0033(대부업)',
#     'BUP_NM': '선유대부',
#     'REP_NM': '김준영',
#     'UPCHE_GBN': '개인',
#     'WRKR_BUP_TELNO': '',
#     'WRKR_BUP_ADDR': '서울특별시 강서구 가양동  14번지 51호  토피아빌딩',
# ...

# %%
result_dict['GangseoListLoanCompany']['RESULT']['CODE']
# Out:
# 'INFO-000'

# %%
sample_df = pd.DataFrame(result_dict['GangseoListLoanCompany']['row'])
sample_df
# Out:
#   BSNS_SE MNG_STATE_CODE              OLD_APV_NO            BUP_NM REP_NM  \
# 0   대부중개업             폐업  2015-서울강서-00033(대부중개업)  주식회사 론마음파트너스대부중개    김진영
# 1     대부업             폐업     2020-서울강서-0033(대부업)              선유대부    김준영
# 2   대부중개업            영업중   2021-서울강서-0036(대부중개업)            EU대부중개    최영우
# 3   대부중개업             폐업   2021-서울강서-0014(대부중개업)     와이앤제이컨설팅 대부중개    윤효선
# 4     대부업            영업중     2021-서울강서-0053(대부업)              꽃길대부    김정근
#
#   UPCHE_GBN WRKR_BUP_TELNO                   WRKR_BUP_ADDR  \
# 0        법인    02-521-1012  서울특별시 강서구 등촌동  696번지  세신그린코아빌딩
# 1        개인                 서울특별시 강서구 가양동  14번지 51호  토피아빌딩
# 2        개인                     서울특별시 강서구 마곡동  798번지 17호
# 3        개인                      서울특별시 강서구 마곡동  774번지 1호
# 4        개인                 서울특별시 강서구 공항동  60번지 118호  대성빌딩
#
#                               WRKR_RD_FULL_ADDR WRKR_BUP_POST_NO   APV_YMD  \
# 0  서울특별시 강서구 공항대로41길 51, 세신그린코아빌딩 9층 905호 (등촌동)                   20210712
# ...

# %%
sgg_pop_df = pd.read_csv('./files/report.txt', sep = '\t', header = 2)
sgg_pop_df
# Out:
#           기간   자치구         세대          계         남자         여자        계.1  \
# 0   2020.3/4    합계  4,405,833  9,953,009  4,840,912  5,112,097  9,699,232
# 1   2020.3/4   종로구     74,861    159,842     77,391     82,451    149,952
# 2   2020.3/4    중구     63,594    135,321     66,193     69,128    125,800
# 3   2020.3/4   용산구    112,451    244,953    119,074    125,879    229,786
# 4   2020.3/4   성동구    136,096    302,695    147,582    155,113    295,591
# 5   2020.3/4   광진구    166,857    361,923    174,077    187,846    348,064
# 6   2020.3/4  동대문구    167,232    358,679    176,433    182,246    344,416
# 7   2020.3/4   중랑구    185,109    400,989    198,012    202,977    395,997
# 8   2020.3/4   성북구    195,379    449,871    216,155    233,716    439,719
# 9   2020.3/4   강북구    145,790    313,550    152,458    161,092    309,996
# 10  2020.3/4   도봉구    139,029    329,300    160,526    168,774    327,248
# 11  2020.3/4   노원구    218,002    529,532    255,618    273,914    525,486
# ...

# %%
def seoul_open_api_data(url, service):
    data_list = None
    
    try:
        result_dict = requests.get(url).json()
        result_data = result_dict[service]
        code = result_data['RESULT']['CODE']
        
        if code == 'INFO-000':
            data_list = result_data['row']
    except:
        pass
    
    return data_list

# %%
SEOUL_API_AUTH_KEY = '***'
Open_API = 'GangseoListLoanCompany'
url = 'http://openAPI.seoul.go.kr:8088/{}/json/{}/1/5/'.format(SEOUL_API_AUTH_KEY, Open_API)

# %%
sgg_pop_df.columns
# Out:
# Index(['기간', '자치구', '세대', '계', '남자', '여자', '계.1', '남자.1', '여자.1', '계.2',
#        '남자.2', '여자.2', '세대당인구', '65세이상고령자'],
#       dtype='object')

# %%
new_columns = {
    '기간': 'GIGAN',
    '자치구': 'JACHIGU',
    '계': 'GYE_1',
    '계.1': 'GYE_2',
    '계.2': 'GYE_3',
    '남자': 'NAMJA_1',
    '남자.1': 'NAMJA_2',
    '남자.2': 'NAMJA_3',
    '여자': 'YEOJA_1',
    '여자.1': 'YEOJA_2',
    '여자.2': 'YEOJA_3',
    '세대': 'SEDAE',
    '세대당인구': 'SEDAEDANGINGU',
    '65세이상고령자': 'N_65SEISANGGORYEONGJA'
}

sgg_pop_df.rename(columns = new_columns, inplace = True)
sgg_pop_df
# Out:
#        GIGAN JACHIGU      SEDAE      GYE_1    NAMJA_1    YEOJA_1      GYE_2  \
# 0   2020.3/4      합계  4,405,833  9,953,009  4,840,912  5,112,097  9,699,232
# 1   2020.3/4     종로구     74,861    159,842     77,391     82,451    149,952
# 2   2020.3/4      중구     63,594    135,321     66,193     69,128    125,800
# 3   2020.3/4     용산구    112,451    244,953    119,074    125,879    229,786
# 4   2020.3/4     성동구    136,096    302,695    147,582    155,113    295,591
# 5   2020.3/4     광진구    166,857    361,923    174,077    187,846    348,064
# 6   2020.3/4    동대문구    167,232    358,679    176,433    182,246    344,416
# 7   2020.3/4     중랑구    185,109    400,989    198,012    202,977    395,997
# 8   2020.3/4     성북구    195,379    449,871    216,155    233,716    439,719
# 9   2020.3/4     강북구    145,790    313,550    152,458    161,092    309,996
# 10  2020.3/4     도봉구    139,029    329,300    160,526    168,774    327,248
# ...

# %%
sgg_pop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GIGAN                  26 non-null     object
#  1   JACHIGU                26 non-null     object
#  2   SEDAE                  26 non-null     object
#  3   GYE_1                  26 non-null     object
#  4   NAMJA_1                26 non-null     object
#  5   YEOJA_1                26 non-null     object
#  6   GYE_2                  26 non-null     object
#  7   NAMJA_2                26 non-null     object
#  8   YEOJA_2                26 non-null     object
#  9   GYE_3                  26 non-null     object
#  10  NAMJA_3                26 non-null     object
#  11  YEOJA_3                26 non-null     object
#  12  SEDAEDANGINGU          26 non-null     float64
#  13  N_65SEISANGGORYEONGJA  26 non-null     object
# dtypes: float64(1), object(13)
# ...

# %%
sgg_pop_df['JACHIGU']
# Out:
# 0       합계
# 1      종로구
# 2       중구
# 3      용산구
# 4      성동구
# 5      광진구
# 6     동대문구
# 7      중랑구
# 8      성북구
# 9      강북구
# 10     도봉구
# 11     노원구
# 12     은평구
# 13    서대문구
# 14     마포구
# 15     양천구
# 16     강서구
# 17     구로구
# 18     금천구
# 19    영등포구
# 20     동작구
# 21     관악구
# 22     서초구
# 23     강남구
# 24     송파구
# 25     강동구
# Name: JACHIGU, dtype: object

# %%
sgg_pop_df_select = sgg_pop_df[(sgg_pop_df['JACHIGU']!='합계')]
sgg_pop_df_select
# Out:
#        GIGAN JACHIGU    SEDAE    GYE_1  NAMJA_1  YEOJA_1    GYE_2  NAMJA_2  \
# 1   2020.3/4     종로구   74,861  159,842   77,391   82,451  149,952   73,024
# 2   2020.3/4      중구   63,594  135,321   66,193   69,128  125,800   61,526
# 3   2020.3/4     용산구  112,451  244,953  119,074  125,879  229,786  110,604
# 4   2020.3/4     성동구  136,096  302,695  147,582  155,113  295,591  144,444
# 5   2020.3/4     광진구  166,857  361,923  174,077  187,846  348,064  168,095
# 6   2020.3/4    동대문구  167,232  358,679  176,433  182,246  344,416  170,748
# 7   2020.3/4     중랑구  185,109  400,989  198,012  202,977  395,997  195,981
# 8   2020.3/4     성북구  195,379  449,871  216,155  233,716  439,719  212,151
# 9   2020.3/4     강북구  145,790  313,550  152,458  161,092  309,996  151,117
# 10  2020.3/4     도봉구  139,029  329,300  160,526  168,774  327,248  159,723
# 11  2020.3/4     노원구  218,002  529,532  255,618  273,914  525,486  253,797
# ...

# %%
sgg_pop_df_final = sgg_pop_df_select[['JACHIGU','GYE_1']]
sgg_pop_df_final.columns =['시군구명','주민등록인구']
sgg_pop_df_final
# Out:
#     시군구명   주민등록인구
# 1    종로구  159,842
# 2     중구  135,321
# 3    용산구  244,953
# 4    성동구  302,695
# 5    광진구  361,923
# 6   동대문구  358,679
# 7    중랑구  400,989
# 8    성북구  449,871
# 9    강북구  313,550
# 10   도봉구  329,300
# 11   노원구  529,532
# 12   은평구  485,842
# 13  서대문구  323,860
# 14   마포구  383,494
# 15   양천구  460,048
# 16   강서구  589,536
# 17   구로구  435,751
# 18   금천구  249,641
# 19  영등포구  405,982
# 20   동작구  404,617
# 21   관악구  514,555
# 22   서초구  429,995
# 23   강남구  544,085
# 24   송파구  676,673
# 25   강동구  462,275

# %%
sgg_pop_df_final.to_excel('./files/sgg_pop.xlsx', index = False)

# %% [markdown]
# ---
# report2 파일을 불러와서 자치구,소계,종사자수,사업체수 뽑아내기
# - columns : ['시군구명', '종사자수','사업체수']
# - 동 ==  소계

# %%
sgg = pd.read_csv('./files/report2.txt', header = 2, sep = '\t')
sgg
# Out:
#        기간  자치구     동     사업체수    여성대표자          계          남          여  \
# 0    2018   합계    합계  823,385  279,711  5,210,936  2,878,227  2,332,709
# 1    2018  종로구    소계   39,952   13,442    265,017    152,717    112,300
# 2    2018  종로구   사직동    3,541    1,191     49,536     28,658     20,878
# 3    2018  종로구   삼청동      712      324      4,577      2,193      2,384
# 4    2018  종로구   부암동      565      240      3,609      1,706      1,903
# ..    ...  ...   ...      ...      ...        ...        ...        ...
# 445  2018  강동구  둔촌1동       19        4        341        230        111
# 446  2018  강동구  둔촌2동    1,601      567      9,718      4,800      4,918
# 447  2018  강동구  암사1동    1,916      677      5,756      2,957      2,799
# 448  2018  강동구  천호2동    3,736    1,500     14,933      7,104      7,829
# 449  2018  강동구    길동    5,172    1,447     19,657     10,514      9,143
#
#     사업체수.1 종사자수  ... 사업체수.15  종사자수.14 사업체수.16  종사자수.15 사업체수.17  종사자수.16  \
# ...

# %%
sgg_01 = sgg[sgg['동']=='소계']
sgg_01
sgg_02 = sgg_01[['자치구','계','사업체수']]
sgg_02.columns=['시군구명', '종사자수','사업체수']
sgg_biz_df_final = sgg_02.reset_index(drop=True)
sgg_biz_df_final
# Out:
#     시군구명     종사자수    사업체수
# 0    종로구  265,017  39,952
# 1     중구  390,530  60,957
# 2    용산구  141,216  20,813
# 3    성동구  174,819  27,868
# 4    광진구  127,879  24,535
# 5   동대문구  140,748  31,878
# 6    중랑구  103,016  28,024
# 7    성북구  108,201  23,287
# 8    강북구   72,418  18,918
# 9    도봉구   74,314  18,894
# 10   노원구  118,713  26,616
# 11   은평구   90,049  24,873
# 12  서대문구  109,490  19,796
# 13   마포구  255,152  37,232
# 14   양천구  123,311  26,126
# 15   강서구  248,204  38,524
# 16   구로구  218,070  38,553
# 17   금천구  234,012  32,472
# 18  영등포구  367,557  42,589
# 19   동작구  112,564  19,916
# 20   관악구  113,944  26,105
# 21   서초구  438,733  46,540
# 22   강남구  694,136  71,373
# 23   송파구  342,853  47,772
# 24   강동구  145,990  29,772

# %%
sgg_biz_df_final.to_excel('./files/sgg_biz_class.xlsx', index = False)

# %%
starbugs_gu = pd.read_excel('./files/seoul_starbucks_list_class.xlsx')
starbugs_gu
# Out:
#          매장명         위도          경도     매장타입  \
# 0    역삼아레나빌딩  37.501087  127.043069  general
# 1     논현역사거리  37.510178  127.022223  general
# 2    신사역성일빌딩  37.514132  127.020563  general
# 3     국기원사거리  37.499517  127.031495  general
# 4    대치재경빌딩R  37.494668  127.062583  reserve
# ..       ...        ...         ...      ...
# 563     사가정역  37.579594  127.087966  general
# 564      상봉역  37.596890  127.086470  general
# 565    묵동이마트  37.613433  127.077484  general
# 566       묵동  37.615368  127.076633  general
# 567      중화역  37.601709  127.078411  general
#
#                                               주소       전화번호
# 0                        서울특별시 강남구 언주로 425 (역삼동)  1522-3232
# 1                       서울특별시 강남구 강남대로 538 (논현동)  1522-3232
# 2                       서울특별시 강남구 강남대로 584 (논현동)  1522-3232
# 3                       서울특별시 강남구 테헤란로 125 (역삼동)  1522-3232
# 4                     서울특별시 강남구 남부순환로 2947 (대치동)  1522-3232
# ...

# %%
starbugsGu =  starbugs_gu['주소']
starbugsGu
# Out:
# 0                          서울특별시 강남구 언주로 425 (역삼동)
# 1                         서울특별시 강남구 강남대로 538 (논현동)
# 2                         서울특별시 강남구 강남대로 584 (논현동)
# 3                         서울특별시 강남구 테헤란로 125 (역삼동)
# 4                       서울특별시 강남구 남부순환로 2947 (대치동)
#                           ...
# 563                              서울특별시 중랑구 면목로 310
# 564                        서울특별시 중랑구 망우로 307 (상봉동)
# 565    서울특별시 중랑구 동일로 932 (묵동, 묵동자이아파트) (묵동이마트 B1층)
# 566          서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층
# 567                         서울특별시 중랑구 봉화산로 35 1,2층
# Name: 주소, Length: 568, dtype: object

# %%
starbugsGu[0].split()
# Out:
# ['서울특별시', '강남구', '언주로', '425', '(역삼동)']

# %%
addGu = []

for gu in starbugsGu:
    adrgu = gu.split()[1]
    addGu.append(adrgu)
    
addGu
# Out:
# ['강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
# ...

# %%
starbugs_gu['시군구명'] = addGu
starbugs_gu
# Out:
#          매장명         위도          경도     매장타입  \
# 0    역삼아레나빌딩  37.501087  127.043069  general
# 1     논현역사거리  37.510178  127.022223  general
# 2    신사역성일빌딩  37.514132  127.020563  general
# 3     국기원사거리  37.499517  127.031495  general
# 4    대치재경빌딩R  37.494668  127.062583  reserve
# ..       ...        ...         ...      ...
# 563     사가정역  37.579594  127.087966  general
# 564      상봉역  37.596890  127.086470  general
# 565    묵동이마트  37.613433  127.077484  general
# 566       묵동  37.615368  127.076633  general
# 567      중화역  37.601709  127.078411  general
#
#                                               주소       전화번호 시군구명
# 0                        서울특별시 강남구 언주로 425 (역삼동)  1522-3232  강남구
# 1                       서울특별시 강남구 강남대로 538 (논현동)  1522-3232  강남구
# 2                       서울특별시 강남구 강남대로 584 (논현동)  1522-3232  강남구
# 3                       서울특별시 강남구 테헤란로 125 (역삼동)  1522-3232  강남구
# 4                     서울특별시 강남구 남부순환로 2947 (대치동)  1522-3232  강남구
# ...

# %% [markdown]
# ---

# %%
starbugs_gu.to_excel('./files/seoul_starbucks_list_class.xlsx', index = False)

# %%
sb_gu_count = starbugs_gu['시군구명'].value_counts()
sb_gu_count
# Out:
# 강남구     88
# 중구      53
# 서초구     48
# 영등포구    40
# 종로구     39
# 송파구     34
# 마포구     33
# 용산구     23
# 강서구     22
# 서대문구    20
# 광진구     17
# 양천구     17
# 강동구     16
# 성북구     14
# 노원구     13
# 구로구     12
# 성동구     12
# 동작구     11
# 금천구     11
# 관악구     11
# 동대문구     9
# 은평구      8
# 중랑구      8
# 강북구      6
# 도봉구      3
# Name: 시군구명, dtype: int64

# %%
type(sb_gu_count)
# Out:
# pandas.core.series.Series

# %%
sb_gu_count_df = pd.DataFrame(sb_gu_count)
sb_gu_count_df
# Out:
#       시군구명
# 강남구     88
# 중구      53
# 서초구     48
# 영등포구    40
# 종로구     39
# 송파구     34
# 마포구     33
# 용산구     23
# 강서구     22
# 서대문구    20
# 광진구     17
# 양천구     17
# 강동구     16
# 성북구     14
# 노원구     13
# 구로구     12
# 성동구     12
# 동작구     11
# 금천구     11
# 관악구     11
# 동대문구     9
# 은평구      8
# 중랑구      8
# 강북구      6
# 도봉구      3

# %%
sb_gu_pvcount_df = starbugs_gu.pivot_table(values = '매장명',
                       index = '시군구명',
                       aggfunc = 'count')
sb_gu_pvcount_df.rename(columns = {'매장명' : '스타벅스 매장 수'}, inplace = True)
sb_gu_pvcount_df
# Out:
#       스타벅스 매장 수
# 시군구명
# 강남구          88
# 강동구          16
# 강북구           6
# 강서구          22
# 관악구          11
# 광진구          17
# 구로구          12
# 금천구          11
# 노원구          13
# 도봉구           3
# 동대문구          9
# 동작구          11
# 마포구          33
# 서대문구         20
# 서초구          48
# 성동구          12
# 성북구          14
# 송파구          34
# 양천구          17
# 영등포구         40
# 용산구          23
# 은평구           8
# 종로구          39
# 중구           53
# 중랑구           8
