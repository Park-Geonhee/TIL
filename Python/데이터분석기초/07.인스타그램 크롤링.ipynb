# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

from bs4 import BeautifulSoup

import pandas as pd
import numpy as np
import time

# %%
ser = Service('../chrome_dirver/chromedriver.exe')
driver = webdriver.Chrome(service = ser)

# %%
url = 'https://www.instagram.com/'
driver.get(url)

# %%
'''
email = '계정을 입력해 주세요'
input_id = 

input_pw = '비밀번호를 입력해 주세요' 
time.sleep(3)
'''

# %%
def insta_searching(word):
    url = 'https://www.instagram.com/explore/tags/'+ word
    
    return url

# %%
word = '제주도맛집'
url = insta_searching(word)
driver.get(url)

# %%
word = '흑돼지'
url = insta_searching(word)
driver.get(url)
#time.sleep(5)

# %%
from selenium.webdriver.common.by import By

# first = driver.find_element_by_css_selector('div._9AhH0')
# 예전 문법; 권장하지 않음

first = driver.find_element(By.CSS_SELECTOR,'div._9AhH0')

first.click()

# %%
#content,  tags, like, place

# %%
html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')
soup.head()

# %% [markdown]
# ---
# ###### 혼자서 연습

# %%
# 게시글
soup.select('div.C4VMK span')[1].text
# Out:
# '✔✔✔ 11시오픈합니다✔✔✔.불편하시더라도 QR체크및 손소독발열체크 후 입장하시고 백신패스 확인증 미리 준비해주시길 부탁드립니다 🙏....둘이서 재료준비를하기에 많은양을 준비하기가힘이듭니다\xa0 재료소진시 조기마감 될수있어용~🤗. ..✔서귀포시 성산읍 일출로270-8 (민트색건물2층)✔운영시간 11:00-16:00✔마지막주문 15:00✔노브레끼탐🤙✔반려동물은 안되용😭✔노키즈존(14세미만)'

# %%
# 좋아요 수
soup.select('div.Nm9Fw')#[0].text
# Out:
# [<div class="Nm9Fw"><a class="zV_Nj" href="/p/CY0EV9ZPAt8/liked_by/" tabindex="0">좋아요 <span>179</span>개</a></div>]

# %%
# 조회수
soup.select('span.vcOH2')[0].text
# Out:
# '조회 48회'

# %%
# 해시태그
for i in range(len(soup.select('a.xil3i'))):
    print(soup.select('a.xil3i')[i].text)
# Out:
# #성산맛집
# #성산일출봉맛집
# #성산돈까스
# #스누피가든
# #성산카페
# #제주도맛집
# #제주맛집
# #서귀포맛집
# #표선맛집
# #우도맛집
# #세화맛집
# #종달리맛집
# #송당맛집
# #섭지코지맛집
# #월정리맛집
# #성산해물라면맛집
# #성산일출봉돈까스
# #스누피가든맛집

# %% [markdown]
# ---

# %%
from selenium.webdriver.common.by import By

def select_first(driver):
    first = driver.find_element(By.CSS_SELECTOR, 'div._9AhH0')
    first.click()
    time.sleep(3)
    
select_first(driver)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
import unicodedata
# 콘텐츠
content = soup.select('div.C4VMK > span')[0].text
content = unicodedata.normalize('NFC',content)
content
# Out:
# '✔✔✔ 11시오픈합니다✔✔✔.불편하시더라도 QR체크및 손소독발열체크 후 입장하시고 백신패스 확인증 미리 준비해주시길 부탁드립니다 🙏....둘이서 재료준비를하기에 많은양을 준비하기가힘이듭니다\xa0 재료소진시 조기마감 될수있어용~🤗. ..✔서귀포시 성산읍 일출로270-8 (민트색건물2층)✔운영시간 11:00-16:00✔마지막주문 15:00✔노브레끼탐🤙✔반려동물은 안되용😭✔노키즈존(14세미만)'

# %%
import re
# 글자를 다루는 모듈

# %%
# 태그
tags = re.findall(r'#[\s#,\\]+',content)
tags
# 본문에 해시태그가 있을 때, #word 형식으로 추출
# 실습 진행시기(22.01.17 13:30경)에서는 본문에 해시태그가 없음
# https://wikidocs.net/4308 (정규식)
# Out:
# []

# %%
#date = soup.select('time.FH9sR.RhOlS.Nzb55')[0]['datetime']
date = soup.select('time')[0]['datetime'][:10]
date
# Out:
# '2022-01-17'

# %%
like_1 = soup.select('div.Nm9Fw > a > span')[0].text
like_1
# Out:
# '179'

# %%
like_2 = soup.select('a.zV_Nj > span')[0].text
like_2
# Out:
# '179'

# %%
place = soup.select('a.O4GlU')[0].text
place = unicodedata.normalize('NFC',place)
place
# Out:
# '소길별하'

# %%
def get_contents(driver):
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    
    try:
        content = soup.select('div.C4VMK > span')[0].text
        content = unicodedata.normalize('NFC',content)
    except:
        content = ""
    
    try :
        tags = re.findall(r'#[^\s#,\\]+',content)
    except:
        tags =""
        
    date = soup.select('time')[0]['datetime'][:10]
    
    try:
        like = soup.select('a.zV_Nj > span')[0].text
    except :
        like = 0
    
    try:
        place = soup.select('a.O4GlU')[0].text
        place = unicodedata.normalize('NFC',place)
    except:
        place = ""
        
    data = [content, tags, date, like, place]
    
    return data

# %%
get_contents(driver)
# Out:
# ['..#동백식당#갈비살#한라산..일을 열심히 했으니 ㅎㅎ한잔 적셔줘야죠?😍😍집근처  고깃집ㅎㅎ아부지.어머니.친구랑 나푸짐하게 먹어봅시다ㅋ아부지 계셔서 사진을 못찍겠어🤣🤣🤣🤣🤣🤣🤣대충 한장만 찍고..아부지랑 짠...친구는 제주시로 가야하니.ㅋ술 못먹고ㅋㅋ오늘은 아부지랑 짠짠✌✌..#제주도 #제주도맛집#서귀포맛집 #한라봉#친구#홈파티#요리사#참이슬#korea#플레이팅#맛집#안주#수원#수원맛집#먹방#소주#요리#술스타그램#요리스타그램#재희포차#온더테이블#대구맛집#부산맛집#제주도맛집#요리하는남자#레시피테러리스트',
#  ['#동백식당',
#   '#갈비살',
#   '#한라산..일을',
#   '#제주도',
#   '#제주도맛집',
#   '#서귀포맛집',
#   '#한라봉',
#   '#친구',
#   '#홈파티',
#   '#요리사',
#   '#참이슬',
#   '#korea',
#   '#플레이팅',
#   '#맛집',
#   '#안주',
#   '#수원',
#   '#수원맛집',
#   '#먹방',
#   '#소주',
#   '#요리',
#   '#술스타그램',
#   '#요리스타그램',
#   '#재희포차',
#   '#온더테이블',
#   '#대구맛집',
#   '#부산맛집',
#   '#제주도맛집',
#   '#요리하는남자',
#   '#레시피테러리스트'],
#  '2022-01-16',
#  '422',
#  'Seogwipo']

# %%
# 다음 페이지로 넘어가기
def move_next(driver):
    next_button = driver.find_element(By.CSS_SELECTOR,'div.l8mY4.feth3')
    next_button.click()
    time.sleep(3)

# %%
move_next(driver)

# %%
myList = []
for _ in range(3):
    myList.append(get_contents(driver))
    move_next(driver)
myList
# Out:
# [['..#동백식당#갈비살#한라산..일을 열심히 했으니 ㅎㅎ한잔 적셔줘야죠?😍😍집근처  고깃집ㅎㅎ아부지.어머니.친구랑 나푸짐하게 먹어봅시다ㅋ아부지 계셔서 사진을 못찍겠어🤣🤣🤣🤣🤣🤣🤣대충 한장만 찍고..아부지랑 짠...친구는 제주시로 가야하니.ㅋ술 못먹고ㅋㅋ오늘은 아부지랑 짠짠✌✌..#제주도 #제주도맛집#서귀포맛집 #한라봉#친구#홈파티#요리사#참이슬#korea#플레이팅#맛집#안주#수원#수원맛집#먹방#소주#요리#술스타그램#요리스타그램#재희포차#온더테이블#대구맛집#부산맛집#제주도맛집#요리하는남자#레시피테러리스트',
#   ['#동백식당',
#    '#갈비살',
#    '#한라산..일을',
#    '#제주도',
#    '#제주도맛집',
#    '#서귀포맛집',
#    '#한라봉',
#    '#친구',
#    '#홈파티',
#    '#요리사',
#    '#참이슬',
#    '#korea',
#    '#플레이팅',
#    '#맛집',
#    '#안주',
#    '#수원',
#    '#수원맛집',
#    '#먹방',
#    '#소주',
#    '#요리',
#    '#술스타그램',
#    '#요리스타그램',
#    '#재희포차',
#    '#온더테이블',
#    '#대구맛집',
#    '#부산맛집',
#    '#제주도맛집',
#    '#요리하는남자',
#    '#레시피테러리스트'],
#   '2022-01-16',
#   '422',
#   'Seogwipo'],
#  ['22.01.17부터 천국의 계단 사시미&제주 갈치초밥 신메뉴 개시!! ✅한라봉스시 “천국의계단” 메뉴 네이버 예약제 개시 네이버에서 한라봉스시를 검색해주세요.✅ (유선 예약은 불가. 예약이 가득 차 있어도 현장 접수로 이용가능!!)제주도 애월 🍊한라봉스시🍊 천국의계단이 !!신선한 사시미와 제주갈치 버젼으로 새롭게 출시 되었습니다!! 🔅1월 중순 출시예정!🔅 줄서는 맛집의 재료가 신선한 이유!! 다 알고계시죠?? 제주 애월 최고의 오션뷰 최고의 핫플!! 로맨틱 제주 놓치지마세요!! 비쥬얼뿐만 아니라 퀄리티있는 제주 최고의 초밥 한라봉스시와 함께 하세요. 입맛을 만족시키는 실력, 마음을 사로잡는 능력이 있는 매력적인 한라봉스시 추천드립니다제주시 애월읍 애월북서길 54 2층OPEN 10:00 / CLOSE 21:30LAST ODER 20:30070-4566-9001감사합니다.#애월맛집 #제주도맛집#제주맛집 #애월스시#제주스시#애월횟집#제주횟집 #애월초밥#제주초밥#제주핫플 #한라봉스시 #제주갈치#제주도갈치#애월갈치#제주핫플 #애월핫플 #애월해안도로맛집',
#   ['#애월맛집',
#    '#제주도맛집',
#    '#제주맛집',
#    '#애월스시',
#    '#제주스시',
#    '#애월횟집',
#    '#제주횟집',
#    '#애월초밥',
#    '#제주초밥',
#    '#제주핫플',
#    '#한라봉스시',
#    '#제주갈치',
#    '#제주도갈치',
#    '#애월갈치',
#    '#제주핫플',
#    '#애월핫플',
#    '#애월해안도로맛집'],
#   '2022-01-17',
#   '324',
#   '제주도 애월읍'],
#  ['네이버 추천 식당 중 평타 이상!', [], '2022-01-17', '18', '고집돌우럭-gozipfish']]

# %%
def instar_crawling(word, n):
    #ser = Service('../chrome_dirver/chromedriver.exe')
    #driver = webdriver.Chrome(service = ser)
    insta_searching(word)
    driver.get(url)
    select_first(driver)
    
    for _ in range(n):
        myList.append(get_contents(driver))
        move_next(driver)

# %% [markdown]
# #### 위의 과정을 하나의 함수로 나타내 보기

# %%
driver = webdriver.Chrome(service = ser)

driver.get('https://www.instargram.com')
time.sleep(2)

def ins_crawling(word, n):
    url = insta_searching(word)
    
    driver.get(url)
    time.sleep(5)
    
    select_first(driver)
    time.sleep(5)
    
    #target = n
    results = []
    
    for i in range(n):
        try:
            data = get_contents(driver)
            results.append(data)
            move_next(driver)
        except:
            time.sleep(2)
            move_next(driver)
            
    return results

# %%
result_1 = ins_crawling('제주도맛집',3)
result_1
# Out:
# [['.⠀푸릇푸릇한 감귤나무 밭 한가운데그 곳에서 지글지글 흑돼지를 굽고 있어요.⠀#월정리갈비밥',
#   ['#월정리갈비밥'],
#   '2022-01-17',
#   '206',
#   '월정리갈비밥 서귀포점'],
#  ['.❤제주 인스타 감성스팟!❤제주에서 요기가서 막찍어도인생샷을 건질수있다는곳들을모아봤어!! 여기가서 한번 찰칵 해보고 인스타에 업로드 기기!!@찍어줄 친구소환!!!..#제주맛집 #제주도맛집 #제주공항근처맛집 #제주시맛집 #애월맛집 #중문맛집 #제주공항맛집 #서귀포맛집 #산방산맛집 #신제주맛집 #제주시청맛집 #제주애월맛집 #월정리맛집 #제주여행 #제주핫플',
#   ['#제주맛집',
#    '#제주도맛집',
#    '#제주공항근처맛집',
#    '#제주시맛집',
#    '#애월맛집',
#    '#중문맛집',
#    '#제주공항맛집',
#    '#서귀포맛집',
#    '#산방산맛집',
#    '#신제주맛집',
#    '#제주시청맛집',
#    '#제주애월맛집',
#    '#월정리맛집',
#    '#제주여행',
#    '#제주핫플'],
#   '2022-01-16',
#   '1,281',
#   ''],
#  ['<광고>온가족이 즐길 수 있는 제주갈비국수!!💕✔손소독제 항시 배치(입장시 입구부터 손소독제 마스크 착용후 입장 가능합니다🥰)▪️오픈시간: 07:30 - 17:00▪️전화: 064-782-5105▪️제주시 구좌읍 해맞이해안로 2284▪️매주 화요일 휴무산도롱맨도롱#제주맛집 #제주도맛집 #제주아쿠아플라넷#표선맛집 #성산맛집 #성산일출봉맛집 #구좌읍맛집 #구좌맛집 #비자림맛집 #안돌오름 #광치기해변맛집 #제주고기국수#제주도고기국수 #성산아침식사',
#   ['#제주맛집',
#    '#제주도맛집',
#    '#제주아쿠아플라넷',
#    '#표선맛집',
#    '#성산맛집',
#    '#성산일출봉맛집',
#    '#구좌읍맛집',
#    '#구좌맛집',
#    '#비자림맛집',
#    '#안돌오름',
#    '#광치기해변맛집',
#    '#제주고기국수',
#    '#제주도고기국수',
#    '#성산아침식사'],
#   '2022-01-16',
#   0,
#   '']]

# %%
result_df = pd.DataFrame(result_1)
result_df.columns = ['contents','tags','date','like','place']
result_df
# Out:
#                                             contents  \
# 0  .⠀푸릇푸릇한 감귤나무 밭 한가운데그 곳에서 지글지글 흑돼지를 굽고 있어요.⠀#월정...
# 1  .❤제주 인스타 감성스팟!❤제주에서 요기가서 막찍어도인생샷을 건질수있다는곳들을모아봤...
# 2  <광고>온가족이 즐길 수 있는 제주갈비국수!!💕✔손소독제 항시 배치(입장시 입구부터...
#
#                                                 tags        date   like  \
# 0                                          [#월정리갈비밥]  2022-01-17    206
# 1  [#제주맛집, #제주도맛집, #제주공항근처맛집, #제주시맛집, #애월맛집, #중문맛...  2022-01-16  1,281
# 2  [#제주맛집, #제주도맛집, #제주아쿠아플라넷, #표선맛집, #성산맛집, #성산일출...  2022-01-16      0
#
#          place
# 0  월정리갈비밥 서귀포점
# 1
# 2

# %%
result_df.to_excel('./files/jejuMatjip_crawling.xlsx', index = False)

# %%
jeju_insta_df = pd.DataFrame()

f_list = ['1_crawling_jejudoMatJip.xlsx', '1_crawling_jejudoGwanGwang.xlsx',
         '1_crawling_jejuMatJip.xlsx', '1_crawling_jejuYeoHang.xlsx']

for fname in f_list:
    fpath = './files/' + fname
    temp = pd.read_excel(fpath)
    jeju_insta_df = jeju_insta_df.append(temp)
    
jeju_insta_df.head()
# Out:
#                                              content        date like   place  \
# 0  제주도 도착~~공항근처 #제주분식 에서 먹은 첫식사만족만족!#제주맛집#제주도맛집#제...  2019-01-01  705     NaN
# 1  ﻿#함덕맛집 무거버거 바다 보면서 먹으니까 더 꿀맛👍🏻 #제주도카페투어#제주일상#함...  2019-01-01  384     NaN
# 2  .대만족 제주스!.#동문시장#제주동문시장#제주도기념품#제주기념품#제주스는완벽#제주도...  2019-01-01  595     NaN
# 3  #제주여행#2일차무거버거 제주와서 먹은것중에 제일 맛있었음!#제주도여행#제주맛집#함...  2019-01-01  412     NaN
# 4  🥇1월 영업 안내🥇-1월 2일, 3일(수,목)은 쉬어갑니다-1월 4일,5일,6일(금...  2019-01-01  364  로타리과자점
#
#                                                 tags
# 0  ['#제주분식', '#제주맛집', '#제주도맛집', '#제주맛집추천', '#제주도맛...
# 1  ['#함덕맛집', '#제주도카페투어', '#제주일상', '#함덕', '#jejudo...
# 2  ['#동문시장', '#제주동문시장', '#제주도기념품', '#제주기념품', '#제주...
# 3  ['#제주여행', '#2일차무거버거', '#제주도여행', '#제주맛집', '#함덕맛...
# 4                                                 []

# %%
jeju_insta_df.shape
# Out:
# (12780, 5)

# %%
jeju_insta_df.drop_duplicates(subset = ['content'], inplace = True)
jeju_insta_df.shape
## 완전히 중복된 데이터를 제거하는 pandas 메소드 drop_duplicates
# Out:
# (8369, 5)

# %%
jeju_insta_df.to_excel('./files/1_crawling_raw_class.xlsx', index = False)

# %%
raw_total = jeju_insta_df.copy()

# %%
raw_total.columns
# Out:
# Index(['content', 'date', 'like', 'place', 'tags'], dtype='object')

# %%
raw_total['tags']
# Out:
# 0       ['#제주분식', '#제주맛집', '#제주도맛집', '#제주맛집추천', '#제주도맛...
# 1       ['#함덕맛집', '#제주도카페투어', '#제주일상', '#함덕', '#jejudo...
# 2       ['#동문시장', '#제주동문시장', '#제주도기념품', '#제주기념품', '#제주...
# 3       ['#제주여행', '#2일차무거버거', '#제주도여행', '#제주맛집', '#함덕맛...
# 4                                                      []
#                               ...
# 1702    ['#일상', '#구기자', '#티타임', '#2019', '#새해', '#차스타그...
# 1703    ['#제주', '#친정여행', '#겨울방학', '#제주여행앞머리는', '#친정찬스'...
# 1705                           ['#사진좀찍으시는님덕에건져또', '#이순간']
# 1706                                                   []
# 1707                            ['#HappyNewYearEveryone']
# Name: tags, Length: 8369, dtype: object

# %%
raw_total['tags'][0]
# Out:
# 0    ['#제주분식', '#제주맛집', '#제주도맛집', '#제주맛집추천', '#제주도맛...
# 0    ['#제주핫플레이스', '#제주여행', '#제주여행', '#제주도여행', '#제주가...
# 0                                                   []
# 0                                             ['#제주도']
# Name: tags, dtype: object

# %%
raw_total['tags'][0].str[1:-1]
# Out:
# 0    '#제주분식', '#제주맛집', '#제주도맛집', '#제주맛집추천', '#제주도맛집...
# 0    '#제주핫플레이스', '#제주여행', '#제주여행', '#제주도여행', '#제주가볼...
# 0
# 0                                               '#제주도'
# Name: tags, dtype: object

# %%
# tags_total = []
# for i in range(len(raw_total['tags'])):
#     tags_list = raw_total['tags'][i].str[1:-1]
#     for tag in tags_list:
#         tags_total.append(tag)

# tags_total

# %%
tags_total = []
for tags in raw_total['tags']:
    tags_list = tags[2:-2].split("', '")
    for tag in tags_list:
        tags_total.append(tag)

tags_total
# Out:
# ['#제주분식',
#  '#제주맛집',
#  '#제주도맛집',
#  '#제주맛집추천',
#  '#제주도맛집추천',
#  '#제주도',
#  '#제주맛집',
#  '#용두암',
#  '#신제주맛집',
#  '#연동맛집',
#  '#제주연동맛집',
#  '#애월맛집',
#  '#연동제주분식',
#  '#제주공항근처맛집',
#  '#제주공항맛집',
#  '#돔베김밥',
#  '#전복김밥',
#  '#제주돈까스',
#  '#jeju',
#  '#제주도가볼만한곳',
#  '#함덕맛집',
#  '#제주도카페투어',
#  '#제주일상',
#  '#함덕',
#  '#jejudo',
#  '#jeju',
#  '#제주도맛집',
#  '#함덕맛집무거버거짱',
#  '#일상',
#  '#제주살이',
#  '#제주도살이',
#  '#함덕해수욕장',
#  '#함덕카페',
#  '#함덕맛집',
#  '#제주카페',
#  '#제주도카페',
#  '#제주도맛집추천',
#  '#제주도민',
#  '#제주도민맛집',
#  '#제주도맛집',
#  '#제주맛집',
#  '#제주도여행',
#  '#동문시장',
#  '#제주동문시장',
#  '#제주도기념품',
#  '#제주기념품',
#  '#제주스는완벽',
#  '#제주도맛집',
#  '#제주맛집',
#  '#제주도주스',
#  '#제주도한라봉주스',
#  '#제주도카페',
#  '#제주카페',
#  '#제주도기념품',
#  '#제주기념품',
#  '#제주감성소품',
#  '#제주도여행',
#  '#제주여행',
#  '#2일차무거버거',
#  '#제주도여행',
#  '#제주맛집',
#  '#함덕맛집',
#  '#제주도버거',
#  '#함덕해변',
#  '#제주도맛집추천',
#  '#제주도가볼만한곳',
#  '#여행스타그램',
#  '#제주도수제버거',
#  '#제주여행',
#  '#제주도카페',
#  '#제주도맛집',
#  '#조천읍',
#  '#함덕맛집무거버거짱',
#  '#조천카페',
#  '#함덕해수욕장',
#  '',
#  '#제주마카롱',
#  '#월정리카페콧수염',
#  '#월정리맛집',
#  '#월정리카페',
#  '#월정리',
#  '#구좌읍맛집',
#  '#제주맛집',
#  '#제주도맛집',
#  '#함덕해수욕장',
#  '#제주도민맛집',
#  '#함덕맛집',
#  '#성산맛집',
#  '#구좌맛집',
#  '#애월맛집',
#  '#서귀포맛집',
#  '#인생마카롱',
#  '#마카롱성지',
#  '#서귀포카페',
#  '#성산일출봉맛집',
#  '#섭지코지맛집',
#  '#제주여행',
#  '#제주도여행',
#  '#공항근처맛집',
#  '#구좌읍카페',
#  '#제주해안도로',
#  '#월정리카페거리',
#  '#제주피크닉',
#  '#제주마카롱맛집',
#  '#제주도마카롱',
#  '',
#  '#제주분식',
#  '#제주모닥치기',
#  '#돔베라면',
#  '#돔베덮밥',
#  '#전복김밥',
#  '#돔베김밥',
#  '#먹스타',
#  '#제주도청',
#  '#제주시청맛집',
#  '#제주시맛집',
#  '#제주공항근처맛집',
#  '#제주도맛집',
#  '#제주맛집',
#  '#연동제주분식',
#  '#연동맛집',
#  '#노형동맛집',
#  '#용두암맛집',
#  '#애월맛집',
#  '#제주여행',
#  '#제주흑돼지',
#  '#제주돈까스',
#  '#제주도',
#  '#제주맛집',
#  '#제주도맛집',
#  '#월정리맛집',
#  '#월정리',
#  '#월정리해변',
#  '#월정리해수욕장',
#  '#구좌읍맛집',
#  '#세화맛집',
#  '#성산맛집',
#  '#비자림맛집',
#  '#제주동부맛집',
#  '#제주동쪽맛집',
#  '#김밥맛집',
#  '#제주김밥',
#  '#제주김밥맛집',
#  '#제주도김밥',
#  '#월정리해변',
#  '#제주도가볼만한곳',
#  '#제주도먹거리',
#  '#제주도여행',
#  '#제주맛집추천',
#  '#제주공항근처맛집',
#  '#제주여행코스',
#  '#제주도맛집추천',
#  '#제주맛집투어',
#  '#제주도맛집여행',
#  '#제주도맛집베스트',
#  '#서면클럽',
#  '#커플여행',
#  '#여자옷',
#  '#잠실카페',
#  '#독소',
#  '#강남유앤미',
#  '#강릉카페',
#  '#데일리그램',
#  '#남포동맛집',
#  '#애터미',
#  '#인친환영',
#  '#제주도맛집',
#  '#좋아요꾹',
#  '#수원카페',
#  '#눈썹문신',
#  '#제주분식주소',
#  '#제주도모닥치기',
#  '#전복김밥',
#  '#돔베라면',
#  '#돔베김밥',
#  '#돔베덮밥',
#  '#수제흑돈까스',
#  '#제주맛집',
#  '#제주도맛집',
#  '#제주맛집추천',
#  '#제주도맛집추천',
#  '#제주공항근처맛집',
#  '#제주공항맛집',
#  '#제주도공항맛집',
#  '#제주도공항근처맛집',
#  '#제주공항근처아침식사',
#  '#제주시맛집',
#  '#제주도민맛집',
#  '#신제주맛집',
#  '#연동맛집',
#  '#연동제주분식',
#  '#애월맛집',
#  '#제주맛가볼만한곳',
#  '#제주여행',
#  '#신선포구횟집',
#  '#제주도맛집',
#  '#제주맛집',
#  '#성산맛집',
#  '#성산일출봉',
#  '#제주표선맛집',
#  '#제주도횟집',
#  '#제주횟집',
#  '#표선횟집',
#  '#제주도회포장',
#  '#성산일출봉횟집',
#  '#성산맛집신산포구횟집최고',
#  '#성산일출봉맛집',
#  '#표선맛집',
#  '#육팔청춘이렇게',
#  '#사장님',
#  '#비결이',
#  '#뭐에요.....',
#  '#제주여행코스',
#  '#제주도여행코스',
#  '#제주도코스',
#  '#제주스타그램',
#  '#제주흑돼지',
#  '#제주도흑돼지',
#  '#제주흑돼지맛집',
#  '#제주도흑돼지맛집',
#  '#제주시맛집',
#  '#제주도맛집',
#  '#제주맛집',
#  '#육팔청춘',
#  '#제주공항근처맛집',
#  '#제주공항맛집',
#  '#제주맛집육팔청춘최고',
#  '#제주핫플레이스',
#  '#강릉카페',
#  '#맞팔댓글',
#  '#반영구',
#  '#패션피플',
#  '#좋아요테러',
#  '#육아맘',
#  '#소통그램',
#  '#제주도맛집',
#  '#l4l',
#  '#인천맛집',
#  '#강릉맛집',
#  '#소통해요',
#  '#셀스타',
#  '#인친환영',
#  '#이태원메이드',
#  '#제주도',
#  '#제주맛집',
#  '#제주도맛집',
#  '#월정리맛집',
#  '#월정리',
#  '#월정리해변',
#  '#월정리해수욕장',
#  '#구좌읍맛집',
#  '#세화맛집',
#  '#성산맛집',
#  '#비자림맛집',
#  '#제주동부맛집',
#  '#제주동쪽맛집',
#  '#김밥맛집',
#  '#제주김밥',
#  '#제주김밥맛집',
#  '#제주도김밥',
#  '#월정리해변',
#  '#제주도가볼만한곳',
#  '#제주도먹거리',
#  '#제주도여행',
#  '#제주맛집추천',
#  '#제주공항근처맛집',
#  '#제주여행코스',
#  '#제주여행중',
#  '#제주여행추천',
#  '#제주도맛집추천',
#  '#제주맛집투어',
#  '#애월맛집',
#  '#제주도맛집여행',
#  '#제주도맛집베스트',
#  '#btskimseokjin',
#  '#weloveyouseokjin',
#  '#btsseokjin',
#  '#seokjinbts',
#  '#worldwidehandsomeday',
#  '#seokjinbts',
#  '#boyfriendquotes',
#  '#heartbroke',
#  '#frasessad',
#  '#방탄소년단팬아트',
#  '#김석진',
#  '#방탄소년단진',
#  '#형',
#  '#92년',
#  '#btshyungline',
#  '#대구맛집',
#  '#일산맛집',
#  '#서면맛집',
#  '#서울맛집',
#  '#부산맛집',
#  '#홍대맛집',
#  '#제주도맛집',
#  '#강남맛집',
#  '#방탄소년단',
#  '#한국사랑해',
#  '#사람은',
#  '#아이돌',
#  '#대한민국만세🇰🇷',
#  '#고집돌우럭',
#  '#중문점',
#  '#중문맛집',
#  '#제주중문맛집',
#  '#제주공항근처맛집',
#  '#제주도맛집',
#  '#제주도여행',
#  '#jejufood',
#  '#jeju_korea',
#  '#고집돌우럭jmt',
#  '#제주맛집',
#  '#제주도가볼만한곳',
#  '#제주살이',
#  '#서귀포맛집',
#  '#흑돼지',
#  '#보양식',
#  '#육팔청춘',
#  '#♥',
#  '#여행사진',
#  '#제주여행추천',
#  '#제주여행지',
#  '#제주기념품',
#  '#제주도기념품',
#  '#제주셀프스냅',
#  '#제주흑돼지맛집',
#  '#제주도흑돼지맛집',
#  '#제주시맛집',
#  '#제주도맛집',
#  '#제주맛집',
#  '#제주공항근처맛집',
#  '#제주공항맛집',
#  '#제주맛집육팔청춘최고',
#  '#대구맛집',
#  '#좋아요반사',
#  '#인친해요',
#  '#데일리그램',
#  '#서귀포카페',
#  '#소통그램',
#  '#광주카페',
#  '#강릉카페',
#  '#동성로',
#  '#애터미',
#  '#맞팔해요',
#  '#인스타',
#  '#서면카페',
#  '#제주도맛집',
#  '#인친좋아요',
#  '#제주여행2일차제주산',
#  '#전복김밥',
#  '#제주분식주소',
#  '#제주도맛집',
#  '#제주여행',
#  '#연동맛집',
#  '#노형동맛집',
#  '#제주도청',
#  '#제주시청맛집',
#  '#제주시맛집',
#  '#제주시내맛집',
#  '#연동제주분식',
#  '#먹방그램',
#  '#제주그램',
#  '#제주일상',
#  '#돔베라면',
#  '#제주도김밥',
#  '#돔베덮밥',
#  '#흑돼지돈까스',
#  '#제주도흑돼지',
#  '#새해첫날',
#  '#우도',
#  '#짬뽕라면',
#  '#제주도',
#  '#제주도맛집',
#  '#제주도바람개비',
#  '#바람개비',
#  '#청춘괴기',
#  '#서귀포맛집',
#  '#서귀포흑돼지맛집',
#  '#서귀포맛집추천',
#  '#서귀포시청',
#  '#강정동맛집',
#  '#서귀포신시가지맛집',
#  '#서귀포시청맛집',
#  '#제주도맛집',
#  '#월드컵경기장맛집',
#  '#서귀포맛집청춘괴기최고',
#  '#제주도민',
#  '#제주도민맛집',
#  '#제주도민일상',
#  '#성산옥탑',
#  '#표선카페',
#  '#제주표선레스토랑',
#  '#제주점심',
#  '#성산일출봉점심',
#  '#성산레스토랑',
#  '#표선맛집',
#  '#성산맛집',
#  '#성산맛집성산옥탑최고',
#  '#섭지코지맛집',
#  '#제주도돈까스맛집',
#  '#제주돈까스맛집',
#  '#성산카페',
#  '#제주맛집',
#  '#제주도맛집',
#  '#청춘괴기',
#  '#서귀포맛집청춘괴기최고',
#  '#서귀포맛집추천',
#  '#서귀포시청',
#  '#강정동맛집',
#  '#서귀포신시가지맛집',
#  '#서귀포시청맛집',
#  '#제주도맛집',
#  '#월드컵경기장맛집',
#  '#법환동맛집',
#  '#제주도민',
#  '#제주도민맛집',
#  '#제주도민일상',
#  '#제주',
#  '#제주맛집',
#  '#제주도맛집',
#  '#월정리맛집',
#  '#월정리',
#  '#월정리해변',
#  '#김녕해변',
#  '#함덕해수욕장',
#  '#협재해수욕장',
#  '#카멜리아힐',
#  '#세화맛집',
#  '#세화해변맛집',
#  '#성산맛집',
#  '#맛집',
#  '#김밥맛집',
#  '#제주김밥',
#  '#제주도김밥',
#  '#제주가볼만한곳',
#  '#제주도가볼만한곳',
#  '#제주먹방',
#  '#제주도여행맛집',
#  '#제주여행맛집',
#  '#제주맛집추천',
#  '#제주공항',
#  '#제주공항맛집',
#  '#제주도맛집투어',
#  '#제주맛집여행',
#  '#제주맛집베스트',
#  '#맛스타그램.',
#  '#매운돼지갈비찜',
#  '#쫀득만두',
#  '#돈까스정식.제주에서',
#  '#20181215',
#  '#제주도맛집',
#  '#제주도민맛집',
#  '#착한맛집',
#  '#밀면맛집',
#  '#제주도밀면맛집',
#  '#제주여행가야밀면',
#  '#맛있다그램',
#  '#JMT',
#  '#맛집도장깨기',
#  '#인스타맛집',
#  '#존맛',
#  '#맛있다그램',
#  '#제주도여행',
#  '#신제주맛집',
#  '#food',
#  '#instafood',
#  '#맛집추천',
#  '#강남아이린',
#  '#대전카페',
#  '#인친들',
#  '#선팔환영',
#  '#부산아레나',
#  '#강남',
#  '#이태원메이드',
#  '#건대',
#  '#독소',
#  '#가로수길',
#  '#워킹맘',
#  '#이태원파운틴',
#  '#강남카페',
#  '#소통그램',
#  '#맞팔댓글',
#  '#제주도맛집',
#  '#강남테란',
#  '#럽스타그램',
#  '#대전맛집',
#  '#인천카페',
#  '#고집돌우럭가성비',
#  '#고집돌우럭',
#  '#제주맛집',
#  '#jeju',
#  '#제주도맛집',
#  '#제주앓이',
#  '#제주도민맛집',
#  '#제주시맛집',
#  '#제주여행',
#  '#제주공항근처맛집',
#  '#고집돌우럭jmt',
#  '#jejuisland',
#  '#제주맛집추천',
#  '#제주맛집',
#  '#서귀포맛집',
#  '#올레시장맛집',
#  '#제주맛집마라내음최고',
#  '#제주도맛집',
#  '#제주여행',
#  '#제주도여행',
#  '#이중섭거리맛집',
#  '#마라내음',
#  '#서귀포핫플',
#  '#서귀동맛집',
#  '#이중섭거리',
#  '#제주도마라롱샤',
#  '#마라롱샤',
#  '#아지트샵임하나',
#  '#아지트샵',
#  '#마켓붐',
#  '#헬로우드림',
#  '#마이셀즈',
#  '#아기한복',
#  '#맛집그램',
#  '#핫플맛집',
#  '#강남핫플레이스',
#  '#구미핫플레이스',
#  '#피부비결',
#  '#아기이유식',
#  '#양산맛집추천',
#  '#제주도맛집',
#  '#대학생취미',
#  '#제주맛집',
#  '#육팔청춘',
#  '#제주도민추천맛집',
#  '#제주현지인맛집',
#  '#제주여행중',
#  '#제주흑돼지',
#  '#제주도흑돼지',
#  '#제주흑돼지맛집',
#  '#제주도흑돼지맛집',
#  '#제주시맛집',
#  '#제주도맛집',
#  '#제주공항근처맛집',
#  '#제주공항맛집',
#  '#제주맛집육팔청춘최고',
#  '#제주도여행중',
#  '#제주먹거리',
#  '#제주분식',
#  '#돔베김밥',
#  '#돔베라면',
#  '#돔베덮밥',
#  '#수제흑돈까스',
#  '#먹스타',
#  '#먹방여행',
#  '#제주여행',
#  '#제주도먹방여행',
#  '#제주맛집',
#  '#제주도맛집',
#  '#연동맛집',
#  '#용두암맛집',
#  '#용두암근처맛집',
#  '#연동제주분식',
#  '#제주동문시장',
#  '#제주가볼만한곳',
#  '#전복김밥',
#  '#제주떡볶이',
#  '#캔디원',
#  '#제주도',
#  '#제주도여행',
#  '#제주가족여행',
#  '#제주도가족여행',
#  '#제주도아이와함께가볼만한곳',
#  '#제주도아이와가볼만한곳',
#  '#제주선물',
#  '#제주도선물',
#  '#제주도핫플레이스',
#  '#제주도핫플',
#  '#제주핫플레이스',
#  '#제주핫플',
#  '#육아맘',
#  '#베이비',
#  '#베이비스타그램',
#  '#아들바보',
#  '#딸바보',
#  '#제주기념품',
#  '#제주도기념품',
#  '#맞팔',
#  '#선팔',
#  '#소통',
#  '#인스타그램',
#  '#제주도맛집',
#  '#제주맛집',
#  '#일출투어',
#  '#일출사진관',
#  '#여행에미치다',
#  '#jejuisland',
#  '#용눈이오름',
#  '#다랑쉬오름',
#  '#거문오름',
#  '#비자림',
#  '#만장굴',
#  '#제주여행',
#  '#제주',
#  '#따라비오름',
#  '#표선해수욕장',
#  '#벨롱장',
#  '#워크샵',
#  '#워크샵장소',
#  '#영주산',
#  '#제주도게스트하우스',
#  '#서귀포게스트하우스',
#  '#제주게스트하우스',
#  '#표선게스트하우스',
#  '#세화맛집',
#  '#제주도맛집',
#  '#다희연',
#  '#월정리해변',
#  '#세화해변',
#  '#김녕성세기해변',
#  '#월정리',
#  '#김녕미로공원',
#  '#일출투어',
#  '#제주도일출사진관',
#  '#제주도여행',
#  '#여행에미치다',
#  '#이색워크샵',
#  '#jejuisland',
#  '#제주여행',
#  '#제주',
#  '#따라비오름',
#  '#표선해수욕장',
#  '#우도',
#  '#성산일출봉',
#  '#섭지코지',
#  '#광치기해변',
#  '#김영갑갤러리',
#  '#아쿠아플라넷제주',
#  '#워크샵장소',
#  '#워크샵그램',
#  '#여행스타그램',
#  '#제주도게스트하우스',
#  '#서귀포게스트하우스',
#  '#제주게스트하우스',
#  '#표선게스트하우스',
#  '#제주도맛집',
#  '#김영갑갤러리두모악',
#  '#제주민속촌',
#  '#서연의집',
#  '#외돌개',
#  '#쇠소깍',
#  '#이중섭거리',
#  '#제주도맛집',
#  '#제주맛집',
#  '#애월맛집',
#  '#제주공항근처맛집',
#  '#하귀맛집',
#  '#이호테우해변',
#  '#외도맛집',
#  '#용담해안도로맛집',
#  '#제주해안도로맛집',
#  '#애월해안도로맛집',
#  '#협재맛집',
#  '#중문맛집',
#  '#서귀포맛집',
#  '#제주해물라면',
#  '#제주애월해물라면',
#  '#제주파스타',
#  '#제주전복뚝배기',
#  '#애월읍맛집',
#  '#애월가볼만한곳',
#  '#제주애월가볼만한곳',
#  '#제주전복',
#  '#제주전복맛집',
#  '#제주전복구이',
#  '#제주가볼만한곳',
#  '#제주불빛정원',
#  '#유리성',
#  '#애월라면',
#  '#제주도미용실',
#  '#제주미용실',
#  '#서귀포미용실',
#  '#신산포구횟집',
#  '#제주도맛집',
#  '#제주맛집',
#  '#성산맛집',
#  '#성산일출봉',
#  '#제주표선맛집',
#  '#제주도횟집',
#  '#제주횟집',
#  '#표선횟집',
#  '#제주도회포장',
#  '#성산일출봉횟집',
#  '#성산맛집신산포구횟집최고',
#  '#성산일출봉맛집',
#  '#표선맛집',
#  '#제주맛집',
#  '#함덕무거버거',
#  '#제주수제버거맛집',
#  '#함덕맛집',
#  '#burger',
#  '#제주카페',
#  '#제주맛집추천',
#  '#제주도맛집추천',
#  '#도민맛집',
#  '#제주도민',
#  '#제주도민맛집',
#  '#함덕카페',
#  '#제주도카페',
#  '#제주도맛집',
#  '#함덕',
#  '#조천읍맛집',
#  '#먹스타그램',
#  '#함덕맛집무거버거짱',
#  '#제주도먹방',
#  '#맵찜',
#  '#제주맛집',
#  '#제주맛집맵찜',
#  '#거문오름맛집',
#  '#조천읍맛집',
#  '#제주조천맛집',
#  '#제주도맛집',
#  '#제주맛집추천',
#  '#선흘리맛집',
#  '#매운갈비찜맛집',
#  '#제주도갈비찜',
#  '#배드민턴',
#  '#성수동맛집',
#  '#제주도맛집',
#  '#강남맛집',
#  '#단백질쉐이크',
#  '#홈트',
#  '#최아란',
#  '#바디프로필',
#  '#한남동맛집',
#  '#프로알지',
#  '#영종도카페',
#  '#데일리룩',
#  '#시너지다이어트',
#  '#샤넬',
#  '#신라호텔',
#  '#쇼핑',
#  '#파라다이스호텔',
#  '#시너지',
#  '#시너지디톡스',
#  '#인천배드미턴',
#  '#여행',
#  '#웨딩드레스',
#  '#에르메스',
#  '#청담동맛집',
#  '#홍대맛집',
#  '#파티의상',
#  '#디톡스',
#  '#제주먹방여행전복김밥',
#  '#제주분식제주시',
#  '#제주맛집',
#  '#제주도민맛집',
#  '#제주현지인맛집',
#  '#제주도민',
#  '#먹스타그램',
#  '#제주도먹방',
#  '#제주도그램',
#  '#제주일상',
#  '#신제주맛집',
#  '#제주공항근처맛집',
#  '#제주시맛집',
#  '#연동맛집',
#  '#연동제주분식',
#  '#노형동맛집',
#  '#제주도맛집',
#  '#happybirthday',
#  '#1월1일',
#  '#생일엔',
#  '#보드카선물',
#  '#육팔청춘',
#  '#애월맛집',
#  '#제주흑돼지',
#  '#제주도흑돼지',
#  '#제주흑돼지맛집',
#  '#제주투어',
#  '#제주스냅',
#  '#제주도스냅',
#  '#제주사진',
#  '#제주맛집육팔청춘최고',
#  '#제주도맛집',
#  '#제주맛집',
#  '#제주공항근처맛집',
#  '#제주공항맛집',
#  '#제주애월맛집',
#  '#제주2박3일',
#  '#아지트샵임하나',
#  '#아지트샵',
#  '#마켓붐',
#  '#헬로우드림',
#  '#마이셀즈',
#  '#이태원역',
#  '#결혼후첫생일',
#  '#맛집찾기',
#  '#일산브런치',
#  '#구리네일샵',
#  '#이유식재료',
#  '#피부탄력',
#  '#여수댁',
#  '#피부샾',
#  '#제주도맛집',
#  '#서귀포카페',
#  '#반영구',
#  '#강남카페',
#  '#수원카페',
#  '#제주도맛집',
#  '#데일리그램',
#  '#love',
#  '#아지트샵',
#  '#아레나',
#  '#맞팔환영',
#  '#육아맘일상',
#  '#안산카페',
#  '#방이동카페',
#  '#육아맘',
#  '#옷',
#  '#제주도맛집',
#  '#제주맛집',
#  '#애월맛집',
#  '#제주애월맛집',
#  '#제주공항근처맛집',
#  '#하귀맛집',
#  '#이호테우해변',
#  '#외도맛집',
#  '#용담해안도로맛집',
#  '#제주해안도로맛집',
#  '#협재맛집',
#  '#중문맛집',
#  '#서귀포맛집',
#  '#제주해물라면',
#  '#제주애월해물라면',
#  '#애월해안도로맛집',
#  '#애월라면',
#  '#제주해물뚝기',
#  '#애월전복뚝배기',
#  '#제주해물탕',
#  '#제주가볼만한곳',
#  '#제주도가볼만한곳',
#  '#제주선물',
#  '#제주현지맛집',
#  '#제주불빛정원',
#  '#유리성',
#  '#애월라면',
#  '#제주도미용실',
#  '#제주미용실',
#  '#제주도카페투어',
#  '#제주일상',
#  '#함덕',
#  '#jejudo',
#  '#jeju',
#  '#제주도맛집',
#  '#함덕맛집무거버거짱',
#  '#일상',
#  '#제주살이',
#  '#제주도살이',
#  '#함덕해수욕장',
#  '#함덕카페',
#  '#함덕맛집',
#  '#제주카페',
#  '#제주도카페',
#  '#제주도맛집추천',
#  '#제주도민',
#  '#제주도민맛집',
#  '#제주도맛집',
#  '#제주맛집',
#  '#제주도여행',
#  '#제주도여행',
#  '#제주도맛집',
#  '#제주도브런치',
#  '#제주프리또',
#  '#남친등갈비커리',
#  '#튀김',
#  '#오징어튀김',
#  '#새우튀김',
#  '#감자튀김',
#  '#저녁식사',
#  '#브런치',
#  '#제주스타그램',
#  '#맛스타그램',
#  '#먹스타그램',
#  '#맛있다',
#  '#브런치카페.....',
#  '#협재맛집',
#  '#금능맛집',
#  '#한림맛집',
#  '#한림공원맛집',
#  '#제주맛집',
#  '#월령맛집',
#  '#신창맛집',
#  '#오설록맛집',
#  '#애월맛집',
#  '#한담맛집',
#  '#협재',
#  '#협재해수욕장',
#  '#튀김다발',
#  '#제주프리또',
#  '#제주분식',
#  '#전복김밥',
#  '#돔베라면',
#  '#돔베김밥',
#  '#돔베덮밥',
#  '#제주도맛집',
#  '#제주여행',
#  '#제주스타그램',
#  '#제주그램',
#  '#맛스타그램',
#  '#연동제주분식',
#  '#제주도여행',
#  '#용두암맛집',
#  '#동문시장맛집',
#  '#제주도공항근처맛집',
#  '#제주도공항맛집',
#  '#제주공항맛집',
#  '#제주시내맛집',
#  '#제주도떡볶이',
#  '#제주시맛집',
#  '#고집돌우럭',
#  '#중문맛집',
#  '#제주중문맛집',
#  '#제주공항근처맛집',
#  '#제주도맛집',
#  '#제주도여행',
#  '#jejufood',
#  '#jeju_korea',
#  '#고집돌우럭jmt',
#  '#제주도가볼만한곳',
#  '#제주살이',
#  '#서귀포맛집',
#  '#제주맛집',
#  '#happynewyear',
#  '#2019',
#  '#새해맞이',
#  '#bye2018',
#  '#다이어트',
#  '#안녕',
#  '#먹는게',
#  '#제일좋아',
#  '#친구들모여라',
#  '#육팔청춘',
#  '#제주도동문시장',
#  '#제주도호텔',
#  '#제주도게하',
#  '#제주호텔',
#  '#제주도흑돼지',
#  '#제주흑돼지맛집',
#  '#제주맛집육팔청춘최고',
#  '#제주도흑돼지맛집',
#  '#제주시맛집',
#  '#제주도맛집',
#  '#제주맛집',
#  '#제주공항근처맛집',
#  '#제주공항맛집',
#  '#함덕찜',
#  '#함덕해수욕장맛집',
#  '#제주도',
#  '#제주도맛집',
#  '#제주도여행',
#  '#함덕맛집',
#  '#제주함덕맛집',
#  '#제주도두루치기',
#  '#제주두루치기맛집',
#  '#제주도두루치기맛집',
#  '#제주맛집함덕찜최고',
#  '#제주함덕찜',
#  '#제주맛집',
#  '#happynewyear',
#  '#2019',
#  '#새해맞이',
#  '#bye2018',
#  '#제주분식',
#  '#돔베라면',
#  '#돔베덮밥',
#  '#제주모닥치기',
#  '#돔베김밥',
#  '#돔베고기',
#  '#전복김밥',
#  '#제주맛집',
#  '#제주도맛집',
#  '#제주도연동맛집',
#  '#노형동카페',
#  '#먹스타그램',
#  '#제주여행',
#  '#제주도여행',
#  '#제주도먹방여행',
#  '#연동제주분식',
#  '#제주먹방',
#  '#제주시청맛집',
#  '#용두암',
#  '#제주도청',
#  '#제주도김밥',
#  '#제주김밥',
#  '#제주맛집',
#  '#제주도맛집',
#  '#일상스타그램',
#  '#좋아요',
#  '#제주도',
#  '#제주도여행',
#  '#제주',
#  ...]

# %%
from collections import Counter
tag_counts = Counter(tags_total)

# %%
tag_counts.most_common(50)
# Out:
# [('#제주맛집', 3412),
#  ('#제주도맛집', 3149),
#  ('#제주여행', 3020),
#  ('#제주관광', 2827),
#  ('#제주도', 2053),
#  ('#제주', 1538),
#  ('#제주도여행', 1454),
#  ('#서귀포맛집', 1330),
#  ('#제주도가볼만한곳', 1014),
#  ('#제주핫플레이스', 835),
#  ('#서귀포', 825),
#  ('#jeju', 749),
#  ('#일상', 701),
#  ('#제주흑돼지맛집', 685),
#  ('#제주맛집추천', 675),
#  ('#제주도흑돼지맛집', 669),
#  ('#제주도흑돼지', 663),
#  ('#성산일출봉', 650),
#  ('#제주흑돼지', 648),
#  ('#협재맛집', 602),
#  ('#제주카페', 600),
#  ('#제주도그램', 594),
#  ('#서귀포흑돼지맛집', 593),
#  ('', 587),
#  ('#서귀포흑돼지', 577),
#  ('#제주도민', 570),
#  ('#섭지코지', 556),
#  ('#성산일출봉맛집', 545),
#  ('#섭지코지맛집', 511),
#  ('#선팔', 503),
#  ('#제주가볼만한곳', 497),
#  ('#통갈치구이', 494),
#  ('#제주통갈치구이', 485),
#  ('#제주핫플', 483),
#  ('#제주살이', 480),
#  ('#제주서귀포맛집', 479),
#  ('#제주도민맛집', 477),
#  ('#여행스타그램', 472),
#  ('#제주반영구', 440),
#  ('#제주도관광', 440),
#  ('#여행', 436),
#  ('#제주눈썹문신', 434),
#  ('#서귀포눈썹문신', 420),
#  ('#제주시', 419),
#  ('#제주스타그램', 408),
#  ('#눈썹문신', 405),
#  ('#반영구', 405),
#  ('#중문맛집', 404),
#  ('#제주일상', 398),
#  ('#제주속눈썹', 397)]

# %%
STOPWORDS = ['#일상','#선팔','#제주도','#jeju','#반영구','#제주자연눈썹',
            '#서귀포눈썹문신','#제주눈썹문신','#소통','#맞팔','#제주속눈썹',
            '#제주일상','#여행스타그램','#눈썹문신','#여행',
            '#서귀포반영구','#서귀포속눈썹','#제주남자눈썹문신',
            '#서귀포자연눈썹','#서귀포남자눈썹문신','#카멜리아힐']

tag_total_selected = []

for tag in tags_total:
    if not tag in STOPWORDS:
        tag_total_selected.append(tag)
        
tag_total_selected =Counter(tag_total_selected)

tag_total_selected.most_common(50)
# Out:
# [('#제주맛집', 3412),
#  ('#제주도맛집', 3149),
#  ('#제주여행', 3020),
#  ('#제주관광', 2827),
#  ('#제주', 1538),
#  ('#제주도여행', 1454),
#  ('#서귀포맛집', 1330),
#  ('#제주도가볼만한곳', 1014),
#  ('#제주핫플레이스', 835),
#  ('#서귀포', 825),
#  ('#제주흑돼지맛집', 685),
#  ('#제주맛집추천', 675),
#  ('#제주도흑돼지맛집', 669),
#  ('#제주도흑돼지', 663),
#  ('#성산일출봉', 650),
#  ('#제주흑돼지', 648),
#  ('#협재맛집', 602),
#  ('#제주카페', 600),
#  ('#제주도그램', 594),
#  ('#서귀포흑돼지맛집', 593),
#  ('', 587),
#  ('#서귀포흑돼지', 577),
#  ('#제주도민', 570),
#  ('#섭지코지', 556),
#  ('#성산일출봉맛집', 545),
#  ('#섭지코지맛집', 511),
#  ('#제주가볼만한곳', 497),
#  ('#통갈치구이', 494),
#  ('#제주통갈치구이', 485),
#  ('#제주핫플', 483),
#  ('#제주살이', 480),
#  ('#제주서귀포맛집', 479),
#  ('#제주도민맛집', 477),
#  ('#제주반영구', 440),
#  ('#제주도관광', 440),
#  ('#제주시', 419),
#  ('#제주스타그램', 408),
#  ('#중문맛집', 404),
#  ('#먹스타그램', 395),
#  ('#중문흑돼지맛집', 377),
#  ('#애월맛집', 373),
#  ('#daily', 360),
#  ('#제주메이크업', 358),
#  ('#가족여행', 356),
#  ('#제주도여행코스', 350),
#  ('#jejuisland', 343),
#  ('#성산맛집', 316),
#  ('#셀카', 313),
#  ('#제주해안도로', 311),
#  ('#제주시맛집', 311)]

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import sys
import seaborn as sns

rc('font',family = "malgun gothic")

# %%
tag_count_df = pd.DataFrame(tag_total_selected.most_common(50))
tag_count_df.columns = (['tags','counts'])
tag_count_df.head()

# black 지우기
tag_count_df['tags'].replace('', None, inplace=True)
tag_count_df['tags']
tag_count_df.dropna(subset = ['tags'], inplace = True)

tag_count_df
# Out:
#            tags  counts
# 0         #제주맛집    3412
# 1        #제주도맛집    3149
# 2         #제주여행    3020
# 3         #제주관광    2827
# 4           #제주    1538
# 5        #제주도여행    1454
# 6        #서귀포맛집    1330
# 7     #제주도가볼만한곳    1014
# 8      #제주핫플레이스     835
# 9          #서귀포     825
# 10     #제주흑돼지맛집     685
# 11      #제주맛집추천     675
# 12    #제주도흑돼지맛집     669
# 13      #제주도흑돼지     663
# 14       #성산일출봉     650
# 15       #제주흑돼지     648
# 16        #협재맛집     602
# 17        #제주카페     600
# 18       #제주도그램     594
# 19    #서귀포흑돼지맛집     593
# 20    #서귀포흑돼지맛집     587
# 21      #서귀포흑돼지     577
# 22        #제주도민     570
# 23        #섭지코지     556
# 24     #성산일출봉맛집     545
# 25      #섭지코지맛집     511
# 26     #제주가볼만한곳     497
# 27       #통갈치구이     494
# 28     #제주통갈치구이     485
# 29        #제주핫플     483
# 30        #제주살이     480
# 31     #제주서귀포맛집     479
# 32      #제주도민맛집     477
# 33       #제주반영구     440
# 34       #제주도관광     440
# 35         #제주시     419
# 36      #제주스타그램     408
# 37        #중문맛집     404
# 38       #먹스타그램     395
# 39     #중문흑돼지맛집     377
# 40        #애월맛집     373
# 41       #daily     360
# 42      #제주메이크업     358
# 43        #가족여행     356
# 44     #제주도여행코스     350
# 45  #jejuisland     343
# 46        #성산맛집     316
# 47          #셀카     313
# 48      #제주해안도로     311
# 49       #제주시맛집     311

# %%
plt.figure(figsize = (10, 8))
sns.barplot(x = 'counts', y = 'tags',
           data = tag_count_df)
plt.show()

# %%
# !pip install wordcloud==1.4.1
# Out:
# Collecting wordcloud==1.4.1
#   Downloading wordcloud-1.4.1.tar.gz (172 kB)
# Requirement already satisfied: matplotlib in c:\users\owner\anaconda3\lib\site-packages (from wordcloud==1.4.1) (3.4.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\owner\anaconda3\lib\site-packages (from wordcloud==1.4.1) (1.20.3)
# Requirement already satisfied: pillow in c:\users\owner\anaconda3\lib\site-packages (from wordcloud==1.4.1) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\owner\anaconda3\lib\site-packages (from matplotlib->wordcloud==1.4.1) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\owner\anaconda3\lib\site-packages (from matplotlib->wordcloud==1.4.1) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\owner\anaconda3\lib\site-packages (from matplotlib->wordcloud==1.4.1) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\owner\anaconda3\lib\site-packages (from matplotlib->wordcloud==1.4.1) (0.10.0)
# Requirement already satisfied: six in c:\users\owner\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->wordcloud==1.4.1) (1.16.0)
# Building wheels for collected packages: wordcloud
#   Building wheel for wordcloud (setup.py): started
#   Building wheel for wordcloud (setup.py): finished with status 'error'
#   Running setup.py clean for wordcloud
# Failed to build wordcloud
# Installing collected packages: wordcloud
#     Running setup.py install for wordcloud: started
#     Running setup.py install for wordcloud: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\OWNER\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\OWNER\\AppData\\Local\\Temp\\pip-install-84d4riqx\\wordcloud_7d0d71c1df914f79b5a7550a3eb7c46a\\setup.py'"'"'; __file__='"'"'C:\\Users\\OWNER\\AppData\\Local\\Temp\\pip-install-84d4riqx\\wordcloud_7d0d71c1df914f79b5a7550a3eb7c46a\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\OWNER\AppData\Local\Temp\pip-wheel-8adlhb6o'
#        cwd: C:\Users\OWNER\AppData\Local\Temp\pip-install-84d4riqx\wordcloud_7d0d71c1df914f79b5a7550a3eb7c46a\
#   Complete output (16 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\color_from_image.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\tokenization.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\wordcloud.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\wordcloud_cli.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\__init__.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\stopwords -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\DroidSansMono.ttf -> build\lib.win-amd64-3.9\wordcloud
#   running build_ext
#   building 'wordcloud.query_integral_image' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for wordcloud
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\OWNER\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\OWNER\\AppData\\Local\\Temp\\pip-install-84d4riqx\\wordcloud_7d0d71c1df914f79b5a7550a3eb7c46a\\setup.py'"'"'; __file__='"'"'C:\\Users\\OWNER\\AppData\\Local\\Temp\\pip-install-84d4riqx\\wordcloud_7d0d71c1df914f79b5a7550a3eb7c46a\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\OWNER\AppData\Local\Temp\pip-record-hsshzdz1\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\OWNER\anaconda3\Include\wordcloud'
#          cwd: C:\Users\OWNER\AppData\Local\Temp\pip-install-84d4riqx\wordcloud_7d0d71c1df914f79b5a7550a3eb7c46a\
#     Complete output (16 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\color_from_image.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\tokenization.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\wordcloud.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\wordcloud_cli.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\__init__.py -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\stopwords -> build\lib.win-amd64-3.9\wordcloud
#     copying wordcloud\DroidSansMono.ttf -> build\lib.win-amd64-3.9\wordcloud
#     running build_ext
#     building 'wordcloud.query_integral_image' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\OWNER\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\OWNER\\AppData\\Local\\Temp\\pip-install-84d4riqx\\wordcloud_7d0d71c1df914f79b5a7550a3eb7c46a\\setup.py'"'"'; __file__='"'"'C:\\Users\\OWNER\\AppData\\Local\\Temp\\pip-install-84d4riqx\\wordcloud_7d0d71c1df914f79b5a7550a3eb7c46a\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\OWNER\AppData\Local\Temp\pip-record-hsshzdz1\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\OWNER\anaconda3\Include\wordcloud' Check the logs for full command output.

# %%
from wordcloud import WordCloud
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9900/3266101202.py in <module>
# ----> 1 from wordcloud import WordCloud
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
raw_total.head()
# Out:
#                                              content        date like   place  \
# 0  제주도 도착~~공항근처 #제주분식 에서 먹은 첫식사만족만족!#제주맛집#제주도맛집#제...  2019-01-01  705     NaN
# 1  ﻿#함덕맛집 무거버거 바다 보면서 먹으니까 더 꿀맛👍🏻 #제주도카페투어#제주일상#함...  2019-01-01  384     NaN
# 2  .대만족 제주스!.#동문시장#제주동문시장#제주도기념품#제주기념품#제주스는완벽#제주도...  2019-01-01  595     NaN
# 3  #제주여행#2일차무거버거 제주와서 먹은것중에 제일 맛있었음!#제주도여행#제주맛집#함...  2019-01-01  412     NaN
# 4  🥇1월 영업 안내🥇-1월 2일, 3일(수,목)은 쉬어갑니다-1월 4일,5일,6일(금...  2019-01-01  364  로타리과자점
#
#                                                 tags
# 0  ['#제주분식', '#제주맛집', '#제주도맛집', '#제주맛집추천', '#제주도맛...
# 1  ['#함덕맛집', '#제주도카페투어', '#제주일상', '#함덕', '#jejudo...
# 2  ['#동문시장', '#제주동문시장', '#제주도기념품', '#제주기념품', '#제주...
# 3  ['#제주여행', '#2일차무거버거', '#제주도여행', '#제주맛집', '#함덕맛...
# 4                                                 []

# %%
location_counts = raw_total['place'].value_counts()
location_counts_df = pd.DataFrame(location_counts)
location_counts_df.head()
# Out:
#                       place
# Jeju                    241
# Jeju-do                 172
# Jungle Book by Alice    101
# Seogwipo                 65
# 제주도 크리스마스 박물관            59

# %%
locations = list(location_counts_df.index)
locations
# Out:
# ['Jeju',
#  'Jeju-do',
#  'Jungle Book by Alice',
#  'Seogwipo',
#  '제주도 크리스마스 박물관',
#  '제주에인감귤밭',
#  'Jeju Island',
#  '성산일출봉 城山日出峰  Seongsan Ilchulbong',
#  '폼포코식당_pompokokitchen',
#  '1100고지',
#  'Nimome',
#  '월정리해변',
#  '석부작박물관',
#  '제주도 애월읍',
#  '카멜리아 힐',
#  '알뜨르 비행장',
#  '밥깡패',
#  '고집돌우럭중문점',
#  '제주 함덕 서우봉 해변',
#  '제주레포츠랜드',
#  '제주고궁한복카페 jeju gogung hanbok studio',
#  '제주도 서귀포 중문관광단지 濟州島西歸浦中文觀光團地',
#  '위미동백나무군락지',
#  '할로비치',
#  '제주신화월드 Jeju Shinhwa World',
#  '연동 바오젠 거리',
#  '협재해변 Beach',
#  'Woljeongri Beach',
#  '새별오름',
#  '고래배꼽',
#  '용머리해안',
#  '용눈이오름',
#  '사려니숲길',
#  '김녕미로공원 Jeju Kimnyoung Maze Park',
#  '하이엔드 제주',
#  '제주빅볼랜드',
#  '캔디원',
#  'Jeju Island 제주특별자치도 济州道',
#  '한라산',
#  '마마뜰',
#  '위미동백나무군락',
#  '제주커피박물관 Baum',
#  '휴애리 자연생활공원',
#  '서귀포 느영나영 게스트하우스',
#  '삼무공원',
#  'Jeju Aewol',
#  '위미2리 동백군락지',
#  '한라산 (漢拏山, Hallasan)',
#  '서우봉',
#  '광치기해변',
#  '제주해남',
#  '제주 송악산',
#  '제주어린왕자게스트하우스',
#  '월정리카페콧수염',
#  '옹포별장가든',
#  '성이시돌목장',
#  '제주 꿈꾸는고래 스쿠버&게스트하우스',
#  '산굼부리',
#  '에코랜드',
#  '곽지해수욕장',
#  '牛岛 Udo Island 우도',
#  '아줄레주',
#  '카페브리프',
#  '카페한라산',
#  '르페도라펜션',
#  'Hidden Cliff / 히든 클리프',
#  '디저트쌀롱 톨',
#  '노라바',
#  '르토아베이스먼트',
#  '제주 성산 신산포구자연산횟집 회포장',
#  '오전열한시',
#  '고집돌우럭-gozipfish',
#  '친봉산장',
#  '하도핑크',
#  'Terarosa - 테라로사',
#  '제주동문재래시장',
#  '우아당',
#  'Casa Linda Guesthouse-까사 린다 펜션',
#  '퍼시픽랜드 - Pacific Land JEJU',
#  '우드노트',
#  'the cliff jeju - 더클리프 제주',
#  '제주신라호텔',
#  '제주 협재 해수욕장',
#  '주상절리대',
#  '번개과학체험관',
#  '옹포리',
#  '로타리과자점',
#  '오후새우시',
#  '소세지가게',
#  '비자림',
#  '제주도',
#  '탐라반상',
#  '제주꿈꾸는고래',
#  'Jeju International Airport',
#  'Sunnyside Beachclub Jeju',
#  '세화해수욕장',
#  '춘심이네 본점',
#  '녹근로33',
#  '명월국민학교',
#  '새별오름 (Saebyul Orum)',
#  'LOTTE Hotel Jeju 롯데호텔제주',
#  'Busan, South Korea',
#  '플레이스 캠프 제주',
#  '하늘아래 게스트하우스',
#  '서귀포 매일올레시장',
#  'Hidden Cliff Hotel & Nature',
#  '몽상드 애월 (Mônsant)',
#  '성산일출봉 게스트하우스 파티 띵까게스트하우스',
#  'The Shilla Jeju',
#  '해발1950m 한라산 백록담',
#  '함덕487',
#  '함덕반하다',
#  '서귀포항',
#  '오설록티뮤지엄',
#  'Jungmun Beach',
#  '남원큰엉해안경승지',
#  '만월당',
#  '아날로그감귤체험',
#  '커피캄머',
#  '수목원테마파크',
#  '지금이순간카페',
#  '아름다운 제주도',
#  '안녕협재씨',
#  '안녕김녕sea',
#  '애월늘',
#  '유동커피',
#  '스윗슬로cafe',
#  '설심당본점',
#  'Jejudo',
#  '제주국제공항',
#  '커피파인더coffeefinder제주시청',
#  '이익새양과점',
#  '제주 한라산 영실코스',
#  '대평리',
#  '제주도 월정리',
#  '인생밥집',
#  '제주 남원리',
#  '양가형제',
#  'Paris, France',
#  '로얄',
#  '법환동',
#  '서귀포시 성산읍',
#  '선녀와나무꾼',
#  '금능해변',
#  '앙뚜아네트',
#  '아뜰리에안',
#  '명랑스낵',
#  'Jeju horse Riding farm',
#  'Harmduck Beach in Jeju Island',
#  '쇠소깍',
#  '제주도 세화해변',
#  '제주 산굼부리',
#  '돈사돈',
#  '면차롱',
#  'Hamdeok Jeju',
#  '보름우스테이',
#  '제주도 서귀포',
#  '천지연폭포 (Cheonjiyeon Waterfall)',
#  '제주여행',
#  '하례정원',
#  '한라수목원',
#  '붉은제주',
#  '환상의 섬 Jeju Island',
#  '다람쥐식탁',
#  "블레블랑제리 Ble' Boulangerie",
#  'Seoul, South Korea',
#  'Guzasien -구좌지앵',
#  '제주도 해안도로',
#  '쿠주',
#  '혜화동버거',
#  '푸른섬 제주도',
#  '다랑쉬오름',
#  'Hyatt Regency, Jeju Island',
#  '따라비오름',
#  'Osulloc Tea Museum',
#  '평대리 해변',
#  'Hotel Alfonso XIII, a Luxury Collection Hotel, Seville',
#  '남원읍 신례리',
#  '제주 윗세오름',
#  '제주돌마을공원',
#  '애월해안가',
#  '용두암',
#  'Antoinette',
#  '갈중이',
#  '상호네숯불구이',
#  '어조횟집',
#  '대우정',
#  'Vadada 바다다',
#  '다미진횟집',
#  '슬슬슬로우',
#  '애월더선셋',
#  '한동올레펜션',
#  '테지움 제주',
#  'Hotel NANTA 호텔 난타',
#  '제주 이호해수욕장',
#  '아쿠아 플라넷 제주 (Aqua Planet JEJU)',
#  '비브레이브 커피 로스터즈',
#  '토스카나호텔',
#  '라온더마파크',
#  '남원읍 위미리 귤밭',
#  '켄싱턴 제주호텔',
#  '센트로',
#  '호텔 몽듀',
#  '복자씨연탄구이',
#  '신설오름',
#  '이중섭 거리',
#  '난드르바당',
#  '짱구분식',
#  '중문색달해변 (Jungmun Saekdal Beach)',
#  '김영갑갤러리 두모악',
#  '문치비',
#  '제주서커스월드공연장',
#  '천제연폭포',
#  '외쿡식당',
#  '박물관이살아있다',
#  '군산오름',
#  'Jeju_Gimnyeong_Maze_Park',
#  '빨간머리몽게스트하우스',
#  '동굴카페 다희연(Cafe Daheeyeon in the Cave)',
#  '그러므로part.2',
#  '천지연폭포',
#  '목장카페 드르쿰다',
#  '신창풍차해안도로',
#  '제주도 한경면',
#  '한림항',
#  '제주 서귀포 그릴 데미그라스',
#  '성읍민속마을',
#  '아도록',
#  'Longlive',
#  '영육일삼',
#  '황우지해안',
#  '제주허브동산',
#  '김녕회관',
#  'JEJU앨리스',
#  'Daegu, South Korea',
#  '제주 도두동',
#  '판포리',
#  '소보리당로 222',
#  '바닐라파레트',
#  '모뉴에트',
#  '뉴저지카페',
#  '가시아방',
#  'Namwon Seogwipo Jeju,South korea',
#  '형제국수',
#  '쿠오모제주',
#  '삼미흑돼지',
#  '그초록',
#  '구좌읍 평대리',
#  '우동가게',
#  '그계절',
#  '함덕호랑이',
#  '판포포구',
#  '이정의댁',
#  '로맨틱무브',
#  '제주김만복',
#  '다다의작은공간',
#  'Salon de Lavant',
#  '붉은못허브팜 Cafe Redpond 애월본점',
#  '핏제리아마노',
#  'Ulsan, South Korea',
#  '지오반니',
#  '대정읍',
#  '새연교횟집',
#  '오롯',
#  '카페루핀',
#  '용연구름다리',
#  '카페주비 - JUBI',
#  '초밥충전',
#  '선흘리 동백동산',
#  '하얏트 리젠시 제주ㅣHyatt Regency Jeju',
#  '아부오름',
#  'Teddy Bear Museum - 제주 테디베어뮤지엄',
#  '테쉬폰',
#  '올레7코스',
#  '済州島 - チェジュ島',
#  'Hamdoek Beach, Jeju Island',
#  '제주도 천지연 폭포',
#  '문쏘',
#  'Ecoland Theme Park Forest Train黃花小火車',
#  '제주 구좌읍 세화리',
#  '모슬포항 만선식당',
#  '윗세오름(해발 1700M)',
#  '제주 휴애리',
#  '스튜디오 쿠나',
#  '우도',
#  '제주 조류공원 화조원',
#  '그리울땐 제주',
#  '한림칼국수',
#  '사라봉근처',
#  '순옥이네명가',
#  '백약이 오름',
#  '제주시외버스터미널',
#  '천왕사 (天王寺)',
#  'Meal Table Garden',
#  '서귀포흑돈',
#  '중문 덤장',
#  '쌀다방',
#  '이호테우해변',
#  '밥의정석',
#  '서울맛집',
#  '제주시 동문시장',
#  '앤트러사이트 제주 한림점',
#  '토끼썸',
#  '카페두가시',
#  '테디베어뮤지엄',
#  '이런날엔',
#  '말젯문',
#  '제주도 전주횟집',
#  '빨간모자마법사',
#  '이음',
#  '가시식당',
#  '로컬크랩',
#  '봄날',
#  '제주마방목지',
#  '해왓',
#  '제스토리, 바이제주, 제주감성소품',
#  '연정식당',
#  '볼스카페',
#  '훈이네고사리육개장',
#  '족황상제',
#  '광안리 해수욕장 - 廣安里海水浴場 GwangalliBeach, Busan, South Korea',
#  '칠돈가',
#  'CAFE E.P.L',
#  '모슬 포항',
#  '부두식당',
#  '블리스찬',
#  '한담해안산책로',
#  'Oedolgae Jeju',
#  '보엠 - Bohème',
#  '제주시 아라동',
#  '성산갯마을식당',
#  '평대우유차',
#  '탐나버거',
#  '서귀포 까망돼지',
#  '성산일출봉',
#  '꽃기린 카페',
#  '하도리1091',
#  '컴피하우스',
#  'Cafe148',
#  '자매국수 노형점',
#  '2월22일 브런치카페',
#  '함덕해변',
#  '만세국수삼성혈점',
#  'South Korea',
#  '제주인의밥상',
#  '모이세해장국',
#  '쭈니창고',
#  '모던하우스 제주점',
#  '제주도립미술관',
#  '필립헤어',
#  '협재',
#  '하례리 망장포구',
#  '봉개동',
#  '사락',
#  '자갈자갈',
#  'Cafe카페인',
#  '타시텔레',
#  '제주시 조천읍 와선로 206',
#  '벵디',
#  '오운커피',
#  '공천포 식당',
#  '월정곰닭',
#  '머스태쉬커피/머스태쉬하우스',
#  '해바라기 분식',
#  '해비치호텔&리조트 - Haevichi hotel & resort',
#  '이중섭 미술관',
#  '네이처캔바스',
#  '푸릇프릍',
#  '북촌플레이스',
#  '도토리키친',
#  '카페바띠',
#  '지붕위제주바다',
#  '연화키친',
#  '제주시농협하나로마트',
#  '돈테일러익스프레',
#  '제주도 표선',
#  '제주인에이에이',
#  '쉼표',
#  '오조해녀의집',
#  '로드129',
#  '라비에 와인비스트로',
#  '충남 대천 해수욕장 에서',
#  '비스트로낭',
#  '호박다방',
#  'Salon De 소자38',
#  'Bongcheon-dong',
#  '타쿠마 - Takuma',
#  '비싸이드엠,beside-M',
#  '우도 비양도',
#  '벵디1967',
#  '지금여기',
#  '삼공주회센터',
#  '제주엠리조트',
#  '702키친',
#  'Ulsan, Korea',
#  '명진전복',
#  '도라지식당',
#  '빌라드아토',
#  '수제홍과일모찌하귀점',
#  '인공위성 제주',
#  '제주초가집 곱들락',
#  '대구국제공항',
#  '조천읍 북촌리',
#  'Uncommon Table',
#  '이게밥도둑',
#  '쉐프부부',
#  '숨비아일랜드',
#  'Jamae Guksu',
#  '홍키호테',
#  '젠하이드어웨이',
#  '장복호',
#  '헤밍웨이 하우스',
#  '카페하도섬/엠스테이펜션',
#  '헤이브라더',
#  '카페모리&베이커스트리트',
#  '돈사돈중문점',
#  '백리향백반',
#  '성산포',
#  '1342틈',
#  '아산 음봉',
#  '버드나무집',
#  '덕수하루펜션',
#  'Coco Mama',
#  '소금바치 순이네',
#  '스물다섯',
#  '포근한우리집',
#  '비양도 해녀촌',
#  '하노이안브라더스',
#  '한모살식당',
#  '독개물항',
#  '군산 정상',
#  '제주항공',
#  '반디앤로제이',
#  '한성식당',
#  '성수족발',
#  '호연스테이',
#  '서귀포 기억나는집',
#  "동광 pâtisserie '東光'",
#  '헤이미쉬제주_제주독채펜션',
#  '마모루',
#  '마포식당',
#  '제주시동문시장',
#  '마레벤또',
#  '카페소금',
#  'U-do Bong( 우도봉)',
#  '쿠쿠아림',
#  '마구로쇼쿠도',
#  '털보네고양이',
#  '풍미독서',
#  'Cafe가호',
#  '오메오메동문시장점',
#  '미미본가',
#  "서귀동 298-5 '세계의 가정식'",
#  '바당지기식당',
#  '바다의집',
#  '반딧불 한담',
#  '카페라능',
#  '중문관광단지 (Jungmun Tourism Complex)',
#  'Cultured',
#  '팀버 커피 제주',
#  '73st',
#  '어라운드 폴리 Around Follie',
#  '시루애월 소길점',
#  '바람코지 게스트하우스&카페',
#  '삼다버거',
#  '어반가라지',
#  '시민갈비',
#  '제주시',
#  '서귀포 칼호텔 (KAL Hotel Seogwipo)',
#  '우진해장국',
#  '강식당',
#  'Mansion37.5',
#  '포팩토리',
#  '탑동마차',
#  '바굥식당',
#  '썬앤문리조트',
#  '제주 사랑분식',
#  '가드망제',
#  '제주한면가 濟州韓麵家',
#  '못생김',
#  '중문국수나라',
#  '송당리 풍림다방',
#  'Cafe멘도롱',
#  '드렁큰디제이',
#  '협재칼국수',
#  '과일애',
#  '카페송키',
#  '베이크샵스니프 bakeshop sniff',
#  '홍대개미제주',
#  '리틀이태리 비스트로',
#  '하도해변',
#  '훈남횟집',
#  '섶섬해녀할망카페',
#  '꽃밥',
#  '에코그린리조트',
#  '빌리엔젤 제주노형점',
#  '담앤루리조트',
#  'Bonte museum',
#  '제주도청',
#  '우리두리게스트하우스',
#  'Volskafé',
#  'Maxim 모카다방',
#  '서건도',
#  '외돌개',
#  '목수금토일',
#  'Gimpo International Airport Station',
#  '제주도 하늘 위',
#  'Hwasun',
#  '달사막',
#  '블루라군다이브-bluelagoondive',
#  '절물 자연 휴양림',
#  'Tj Guesthouse',
#  'Gimpo International Airport - 金浦国际机场 - 김포공항',
#  '카페어떤오후',
#  '한라산 정상 해발 1,950m',
#  '평화통일불사리탑사',
#  '호끌락80번지',
#  '카페닐스',
#  '제주 반디앤로제이 펜션 & 플라워브런치카페',
#  '오설록',
#  '접대 - 저번에 우리가 만났던 그때',
#  '종달리 해변',
#  '제주돌문화공원',
#  '피규어뮤지엄제주',
#  '서귀포 워터월드',
#  '김녕장',
#  '한동리 화수목',
#  'Enough, 이너프',
#  '함덕 Fishya',
#  '표선 해비치해수욕장',
#  '게으른날',
#  '에코랜드테마파크',
#  '제주 팜스빌리지',
#  '원더먼트제주',
#  '시월의리브라',
#  '협재 수우동',
#  'Ocean Suites Jeju Hotel',
#  '폴레폴레게스트하우스 -Polepole Guesthouse in Jeju',
#  'M-STAY / 엠스테이',
#  '협재술시',
#  '사라오름 산정호수',
#  '고기마씸',
#  '블루마린하우스',
#  '해물뚝배기전문 재암식당',
#  '골목카페 옥수',
#  '제주도 고근산',
#  'Ramada Plaza Jeju',
#  '제주마로 펜션',
#  '책방무사',
#  '항파두리 항몽유적지',
#  '이호테우 목마등대',
#  '단디501',
#  '마담제 게스트하우스',
#  'Paz',
#  '성산일출봉 코앞 쉼터',
#  'Seosan',
#  '자구리 카페 몬들락 Cafe Mondeulrak',
#  '표선리',
#  '동문시장',
#  '산방굴사 (Sanbanggulsa Temple 山房窟寺)',
#  '十五夜 siboya 십오야',
#  'La Tortuga',
#  'Oslob, Cebu',
#  '중문 마린파크 퍼시픽랜드',
#  '비긴어게인펜션',
#  '제주도 용두암',
#  '바램목장&카페',
#  '개똥이네 동물원',
#  'Saeyeon Bridge, Jeju Island',
#  '종달스토리 게스트하우스',
#  '깡촌흑돼지',
#  '색달식당',
#  '책다방',
#  '제주여행 가야밀면',
#  '구좌상회',
#  '테라로사-이사랑',
#  '스테이 비갠오후',
#  '광안리 앙상블',
#  '제주맑음',
#  '방주교회',
#  '박물관은 살아있다 제주 중문',
#  '몽키비치',
#  '여름문구사',
#  '전주콩나물국밥',
#  '한화아쿠아넷',
#  '객의하우스',
#  '섭지코지 등대',
#  '더아트스테이호텔-The Artstay Hotel',
#  '효돈마을',
#  'MBC',
#  '오렌지블루스',
#  '제주도 휘닉스아일랜드',
#  '시루애월카페',
#  '고근산정상',
#  '잔향',
#  '세종시',
#  '꽃이다카페',
#  '네이처트레일',
#  '제주도 한림',
#  '제주 이호테우 해변',
#  '스테이굿무드',
#  '제주좋은날',
#  '공업탑',
#  '섭지코지 (Seopjikoji)',
#  '고로케야',
#  'Shilla Stay',
#  '내콩가',
#  '신천목장',
#  '해심가든',
#  '제주카페 스르륵',
#  '하늘고래',
#  '구엄리 돌염전',
#  '수카사',
#  '나주혁신도시',
#  '제주 월령선인장 군락지',
#  'Bronx, New York',
#  'The Retrieve',
#  'Kairos jeju',
#  '금악리 제주힐링리조트',
#  '제주시청',
#  '카이로스 제주',
#  '고불락 식당',
#  '제주조천스위스마을',
#  '투썸플레이스 제주애월한담점',
#  '수망일기',
#  '애월해안도로',
#  '올레 6코스 (Olle Route 6)',
#  '사우스바운더 Southbounder Brewery',
#  '모메든식당',
#  '차귀도',
#  '까망고띠',
#  '함덕 다래향',
#  '돈사촌',
#  '지붕 위 제주바다',
#  'Cafe delmundo',
#  '상효원 수목원',
#  '금능반지하',
#  '베케',
#  '바라크라',
#  '유민 아르누보 콜렉션',
#  '안녕, 육지사람',
#  '켄싱턴리조트 서귀포',
#  'TheFirst70 Hotel',
#  '저녁정원',
#  '다이브스테이',
#  '착한스시',
#  'ECOLAND theme park',
#  '신창해안도로',
#  'Soror',
#  '국수의 전설',
#  'BUTTON STAY 단추스테이 게스트하우스',
#  '시리우스 호텔',
#  '나도섬이다',
#  'Howard Johnson Jeju Yeondong Hotel - 하워드존슨 제주 연동 호텔',
#  '제주 성산읍',
#  '제주김만복본점',
#  '제주롯데시네마',
#  '윈드스톤',
#  'playce',
#  '유리의성과마법의숲',
#  '중문 단지 삼원정',
#  '곰막 횟집',
#  '제주도맛집',
#  '동탄2에 산다',
#  '광원',
#  '대돈',
#  '일도전복',
#  '갈치왕',
#  '서귀포 법환포구',
#  '청춘게스트하우스',
#  'Jeju Starbucks 용담dt',
#  'OLD STUFF 올드스터프 Coffee&bread',
#  '외도동',
#  '순덕이네해산물장터',
#  '한복입는 선흘집',
#  '김녕해수욕장 (Gimnyeong Beach)',
#  '돈물국수',
#  '덕인당 소락',
#  '무수천계곡',
#  '제주시 화북동',
#  '자연스러운식당',
#  '제주 대명리조트',
#  '에이그라운드',
#  'Arc de Triomphe',
#  '모니카옛날통닭',
#  '화산양꼬치2호점',
#  'Myeongjin Abalone',
#  '달달콤콤',
#  'Jaju,south Korea',
#  '규태네 양곱창',
#  'KBS본관',
#  '세인트포cc',
#  '쇠소깍오메기식당',
#  '마가리따 은혜씨cafe&Dining pub',
#  'Cafe Ri',
#  '神의 한모(신의 한모)',
#  '카페오길',
#  '풍원 한라산볶음밥',
#  '홍대부부',
#  '모던플레이스 리조트',
#  '성읍칠십리식당',
#  '자구내포구',
#  '큰돈가',
#  '배블리컨테이너',
#  '제주거울미로 이상한나라의앨리스',
#  '피규어 뮤지엄 제주  Figure Museum Jeju',
#  '무거버거',
#  '미풍해장국  중앙점',
#  '나원횟집',
#  '오샹띠',
#  '남원 포구',
#  '서귀포향토오일장',
#  '1158 Cafe',
#  '큰엉전망대쉼터',
#  '동박낭',
#  '김녕 앞바다',
#  'Segovia, Spain',
#  '구좌상회작업실',
#  '가시아방국수',
#  '오드랑베이커리',
#  '사방팔방 외도점',
#  '채점석빵집',
#  '신풍목장',
#  '팔도수산식당',
#  '전주도',
#  '요요무문',
#  '제주도 하도리',
#  '제주프레임스파빌',
#  '대기정',
#  '경성대 맛집',
#  '호텔 아이엠',
#  '아날로그감귤밭',
#  '황궁쟁반짜장',
#  'Hallasan',
#  'Gagamel',
#  '노형로터리',
#  '몽구네민박',
#  '금바리',
#  '건축카페 - 섶섬이보이는',
#  '도두항',
#  '제주시도두항',
#  '렛츠런팜제주',
#  '정관신도시',
#  '우도 하고수동해수욕장',
#  '바보까페',
#  'Cafe기억해',
#  '사계여행',
#  '유채꽃사진촬영소',
#  '스타벅스 제주성산dt점',
#  'Maison GLAD Jeju - 메종글래드 제주',
#  '유리네 식당',
#  '부자식당',
#  'Marevo Resort / 마레보 리조트',
#  '탕196',
#  '형제섬',
#  '동복해녀식당',
#  '종로 광장시장',
#  '김녕함바그집',
#  '검은여식당',
#  '우리집아점',
#  '한라산버섯연구소',
#  '플레이스엉물',
#  '치저스 제주',
#  '동복해녀촌',
#  '웃뜨르 우리돼지',
#  '한림 뽈살집',
#  '덕승식당',
#  '말미오름 (두산봉)',
#  '효섬마을 초가집',
#  '성산스쿠버리조트',
#  '김포 구래동',
#  '제주중문관광단지',
#  '기쁨이네 감자탕',
#  '제주마당',
#  '맥도날드장안사거리점',
#  '테디밸리골프리조트',
#  '하림각',
#  '바다사랑그리고추억',
#  '제주송정농원',
#  '제주 이자와',
#  '카페 하도섬',
#  '국수바다',
#  '괜찮은술책',
#  '제주시 새우리',
#  '라올레( La Olle)',
#  '제주도 올레길 6코스 이중섭거리',
#  '이어도전복해물전문점',
#  '알동네국수',
#  'Villadeato-빌라드아토',
#  '목포고을. 제주도 흑돼지 끝나는 맛!',
#  '흑송',
#  '강정포구',
#  '서귀포흑돼지명가',
#  '하이클래스 제주 (Hiclass Jeju)',
#  '모닝딜라이트제주광양점',
#  '카페록록 Loklok',
#  '부촌식당',
#  '현대백화점 울산점',
#  '여수 앞바다',
#  '양대곱',
#  '오는정 김밥',
#  '뽕끄랑',
#  '홍대 깐풍기브라더스',
#  'CAMPHORTREE Hotel & Resort',
#  '날씬흑돼지',
#  '삼보식당',
#  '주점부리',
#  '수월봉',
#  '흑돼지가있는풍경',
#  '물꼬기',
#  '블랙하우스 떡볶이레스토랑',
#  '대우정식당',
#  '청루 봉평 메밀 막국수',
#  '곱을락',
#  'Thecoffeebrew-더커피브루',
#  '마로니에 공원',
#  '핸드테일러 제주점',
#  '크랩잭제주',
#  '남포커피',
#  '깐깐한족발',
#  '연동포차',
#  '릴리펏 제주점 메종글래드호텔',
#  '오마주마카롱',
#  '담아래',
#  '교래 손 칼국수',
#  '제주돈아',
#  '제주한라수목원♥',
#  '민경이네 어등포해녀촌',
#  'Nolman',
#  '키아스마',
#  '사는맛 먹는맛',
#  '성산옥탑',
#  '정동진',
#  '몽땅카페',
#  '사이카레',
#  '낙지로',
#  '카페오드리',
#  '쉬림포크shrimpork',
#  '듀블라썸',
#  '곽지스테이션',
#  '제주 신재생에너지 홍보관',
#  '한림 바당길',
#  '서양차관',
#  '세영수산',
#  'Gwakji Beaches',
#  'Dammann Frères_다만프레르_제주신화점',
#  '협제 혜변',
#  '보목',
#  '제주아리아',
#  '한림공원 Hallimpark',
#  'Saturdayisland',
#  '서귀포 이마트',
#  'Cafe Koomda',
#  'Seoul, Korea',
#  '한라생태숲',
#  '제주아트리움"비밀의그림자"공연',
#  '관덕정',
#  '알뜨르프로젝트2018',
#  '엉또폭포',
#  '거멍국수',
#  '동문로터리',
#  '청초수물회&섭국 [신관]',
#  '속초 엄지네포장마차',
#  '오라게게스트하우스',
#  '미영이네식당',
#  'Jungle book by Alice',
#  '연북정',
#  '제주스럽닭',
#  '제주 생각하는 정원',
#  '노리매',
#  '탑동해변공연장',
#  '산방산',
#  '제주세계자연유산센터',
#  'Suweolbong Trekking',
#  '제주 나인브릿지 CC',
#  '제주도 부영리조트',
#  '돌마을공원',
#  '화순금모래해변',
#  '제주신라면세점',
#  '돌담너머바다',
#  '니모메빈티지라운지',
#  '나인브릿지',
#  '월정스캔들',
#  '노형 수목원가는길',
#  '저지예술인마을',
#  '기원뚝배기',
#  '산방산 (Sanbangsan)',
#  'Ocean Suite Jeju Hotel (오션스위츠제주호텔)',
#  '내츄럴케이',
#  '바삭돈가스',
#  '아름다운제주여행',
#  '면뽑는선생 만두빚는아내',
#  '소렉',
#  '칠돈가 본점',
#  "Jerry's PUB",
#  '제주칼국수 제주해물탕',
#  '블루밍아일랜드 Blooming Island',
#  '전라북도 군산 경암동 철길마을',
#  '촵촵 - Chwap Chwap',
#  '행원포구',
#  '신흥동 일본식가옥',
#  '8월의크리스마스 초원사진관',
#  '이스트엔드',
#  '제주신화월드 메리어트 리조트관',
#  '스모크하우스인구억',
#  '날것',
#  '카페 호꼼',
#  '수제홍과일모찌',
#  '제주국제공항 활주로 (Jeju Airport Runway)',
#  '올레안뜰',
#  '소우',
#  '바다이야기',
#  '은실이네 게스트하우스',
#  '새우조나단',
#  '속초 아바이마을',
#  '대춘해장국',
#  '금능샌드',
#  'Novotel Ambassador Daegu',
#  '참맛나김밥',
#  '리치망고 협재점',
#  '가배',
#  '떡하니',
#  'Shineville Luxury Resort',
#  '브라운스위트 제주',
#  '고관해물탕, 초량',
#  '엉장매하우스',
#  '키작은삼촌',
#  '토도',
#  '인사리',
#  '한림 칠돈가',
#  '제주시 고요남',
#  '해녀엄마의집',
#  '서촌제',
#  '제주 오션스토리',
#  '제주집',
#  '서머셋 제주신화월드',
#  'Paju',
#  '꽃돼지연탄구이',
#  '제주도 더마파크',
#  'Halim jeju korea Selatan',
#  '제주도 귤밭',
#  '제주마라도잠수함',
#  '제주베니스랜드',
#  '제주하귀휴먼시아',
#  '랍스터빈_jeju',
#  '보롬왓',
#  '종가전복',
#  '스시애월',
#  '서귀포잠수함',
#  '석부작테마공원',
#  '와흘리',
#  '초콜릿랜드 / Chocolate Land',
#  'Yacht Tour Shangri-La',
#  '정방 폭포',
#  '어부의딸',
#  '관음사',
#  '제주비치호텔 함덕',
#  '김녕 성세기 해변',
#  '델문도 제주 카페 Cafe Delmoondo',
#  'Sangumburi Crater',
#  '메이즈랜드',
#  '미도리',
#  '고성리',
#  '더본호텔',
#  'Málaga, Spain',
#  '화북1동',
#  "That's very",
#  '자매국수 본점',
#  '자연뜨락',
#  '비양도',
#  '제주도가는 비행기 안',
#  '제주 천제연폭포',
#  '우도 (Udo / 牛島)',
#  'Teseum',
#  '맛있는 제주',
#  '비자림 (Bija Forest, 榧子林)',
#  '제주함덕 해수욕장',
#  'GD Cafe',
#  '서촌제 (서울촌놈인제주)',
#  '도깨비명당',
#  '스트라이크볼링센터',
#  '서귀포의료원',
#  '제주오리엔탈호텔',
#  'LOTTE City Hotel Jeju 롯데시티호텔제주',
#  '대굴대굴굴구이',
#  '용담해안도로',
#  '정방폭포가 보이는 암벽위',
#  '카페2472',
#  '쪼끌락 cafe',
#  '동한두기',
#  '더스파',
#  '제주중앙로상점가',
#  '환상숲곶자왈공원',
#  '휘슬락호텔',
#  '문섬',
#  '올레길 5코스',
#  '닭머르',
#  '미나마라',
#  '성산수구레국밥',
#  '탑동광장편의점',
#  ...]
